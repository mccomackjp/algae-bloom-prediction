# %% [markdown]
# # Logistic Regression Model

# %% [markdown]
# ## Data Import And Cleaning

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import datetime
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import recall_score, precision_score, confusion_matrix
from sklearn.metrics import roc_curve, auc
import scripts.logistic_regression_functions as lrf
import scripts.helper_functions as hf
from functools import partial
# Out:
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_files = ['../../data/cleaned/utah_2017_vineyard.csv', 
               '../../data/cleaned/utah_2017_marina.csv']

test_files = ['../../data/cleaned/utah_2018_marina.csv',
               '../../data/cleaned/utah_2018_bird.csv']

drop_columns = ['Chlorophyll ug/L', 'Chlorophyll RFU', 'Wiper Pos V',
                'Cable Pwr V', 'Battery V', 'Chlorophyll (ug/L)', 'FDOM RFU']

x_columns = ['Temp C', 'Sp Cond (uS/cm)', 'pH (mV)', 'pH', 'Turbidity (NTU)',
            'ODOSat%', 'ODO (mg/L)']

target_column = 'BGA-Phycocyanin RFU'

# TODO Create average off of minor bloom
RFU_THRESHOLD = 1.2
train_index = 0
test_index = 0
#the operation to be used for math operations during training.
math_operation = partial(np.square)

# %%
# Load the data
train_dfs = lrf.import_df_data(train_files, drop_columns)
test_dfs = lrf.import_df_data(test_files, drop_columns)

train_dfs[train_index].head()
# Out:
#   Date (mm.dd.yyyy) Time 24hr  Temp C  Sp Cond (uS/cm)  pH (mV)    pH  \
# 0          5/5/2017      0:00   15.02             1848   -100.1  8.36
# 1          5/5/2017      0:15   14.99             1847   -100.1  8.36
# 2          5/5/2017      0:30   14.96             1847   -100.1  8.36
# 3          5/5/2017      0:45   14.95             1848   -100.1  8.36
# 4          5/5/2017      1:00   14.92             1848   -100.0  8.36
#
#    Turbidity (NTU)  ODOSat%  ODO (mg/L)  BGA-Phycocyanin RFU
# 0            16.84     90.2        9.04                  0.4
# 1            16.76     90.2        9.04                  0.4
# 2            16.82     90.1        9.04                  0.4
# 3            17.19     90.0        9.03                  0.4
# 4            16.85     89.8        9.02                  0.4

# %%
test_dfs[test_index].head()
# Out:
#   Time America/Boise UTC-06:00  Temp C  Sp Cond (uS/cm)  pH (mV)    pH  \
# 0              4/11/2018 10:30   11.88             1782   -146.1  8.20
# 1              4/11/2018 10:45   11.78             1783   -143.7  8.15
# 2              4/11/2018 11:00   11.79             1784   -144.3  8.17
# 3              4/11/2018 11:15   11.66             1783   -143.1  8.14
# 4              4/11/2018 11:30   11.68             1784   -143.5  8.15
#
#    Turbidity (NTU)  ODOSat%  ODO (mg/L)  BGA-Phycocyanin RFU
# 0            42.49     89.1        9.58                  0.6
# 1            42.89     87.4        9.42                  0.6
# 2            41.24     89.0        9.58                  0.7
# 3            42.65     87.1        9.41                  0.7
# 4            42.06     87.5        9.45                  0.7

# %%
train_dfs[train_index].describe()
# Out:
#              Temp C  Sp Cond (uS/cm)       pH (mV)            pH  \
# count  18947.000000     18947.000000  18947.000000  18947.000000
# mean      18.488235      1933.564575   -116.806951      8.633415
# std        6.134464       151.800551      8.973830      0.147231
# min        5.630000         3.000000   -153.700000      7.930000
# 25%       12.700000      1848.000000   -120.800000      8.530000
# 50%       20.320000      1939.000000   -115.700000      8.650000
# 75%       23.630000      2070.000000   -112.100000      8.700000
# max       28.570000      2164.000000    -76.500000      9.230000
#
#        Turbidity (NTU)       ODOSat%    ODO (mg/L)  BGA-Phycocyanin RFU
# count     18947.000000  18947.000000  18947.000000         18947.000000
# mean         58.129348     87.056980      8.179008             0.979511
# std          54.622278     13.793755      1.278416             0.731423
# min           0.660000     62.800000      5.170000             0.000000
# 25%          29.850000     80.000000      7.260000             0.500000
# 50%          42.140000     83.200000      8.080000             0.900000
# 75%          65.795000     88.900000      9.250000             1.200000
# max         636.700000    209.700000     16.170000            16.100000

# %%
train_dfs[train_index][[target_column]].describe()
# Out:
#        BGA-Phycocyanin RFU
# count         18947.000000
# mean              0.979511
# std               0.731423
# min               0.000000
# 25%               0.500000
# 50%               0.900000
# 75%               1.200000
# max              16.100000

# %%
test_dfs[test_index].describe()
# Out:
#              Temp C  Sp Cond (uS/cm)       pH (mV)            pH  \
# count  19487.000000     19487.000000  19487.000000  19487.000000
# mean      19.131184      1990.294607   -196.624329      8.922357
# std        5.045367       230.743946     27.769024      0.357733
# min        0.000000         0.000000   -284.000000      0.000000
# 25%       15.480000      1869.000000   -216.950000      8.730000
# 50%       20.190000      1958.000000   -192.000000      8.920000
# 75%       23.070000      2149.000000   -179.500000      9.100000
# max       28.600000      2417.000000      0.000000     10.100000
#
#        Turbidity (NTU)       ODOSat%    ODO (mg/L)  BGA-Phycocyanin RFU
# count     19487.000000  19487.000000  19487.000000         19487.000000
# mean         63.929067     90.057202      8.309566             1.459773
# std          70.885989     17.627283      1.486747             1.311960
# min          -0.880000      0.000000      0.000000            -0.400000
# 25%          33.750000     79.100000      7.280000             0.600000
# 50%          48.380000     85.300000      8.010000             1.000000
# 75%          68.275000     95.300000      9.240000             1.700000
# max        1248.920000    245.500000     19.590000            21.100000

# %% [markdown]
# ## Use Datetime Index

# %%
print(test_dfs[test_index].dtypes)
print(train_dfs[train_index].dtypes)
# Out:
# Time America/Boise UTC-06:00     object
# Temp C                          float64
# Sp Cond (uS/cm)                   int64
# pH (mV)                         float64
# pH                              float64
# Turbidity (NTU)                 float64
# ODOSat%                         float64
# ODO (mg/L)                      float64
# BGA-Phycocyanin RFU             float64
# dtype: object
# Date (mm.dd.yyyy)       object
# Time 24hr               object
# Temp C                 float64
# Sp Cond (uS/cm)          int64
# pH (mV)                float64
# pH                     float64
# Turbidity (NTU)        float64
# ODOSat%                float64
# ODO (mg/L)             float64
# BGA-Phycocyanin RFU    float64
# dtype: object

# %%
# We will need to engineer a datetime column for our 2017 data

# Create a single datetime column from the strings provided in our csv's
for i in range(0, len(train_dfs)):
    timestamp = train_dfs[i]['Date (mm.dd.yyyy)'] + ' '+ train_dfs[i]['Time 24hr']
    timestamp = pd.to_datetime(timestamp)
    train_dfs[i]['timestamp'] = timestamp
    train_dfs[i]['datetime'] = timestamp
    train_dfs[i] = train_dfs[i].set_index('timestamp')
    train_dfs[i] = train_dfs[i].drop(columns=['Date (mm.dd.yyyy)', 'Time 24hr'])
train_dfs[train_index].head()
# Out:
#                      Temp C  Sp Cond (uS/cm)  pH (mV)    pH  Turbidity (NTU)  \
# timestamp
# 2017-05-05 00:00:00   15.02             1848   -100.1  8.36            16.84
# 2017-05-05 00:15:00   14.99             1847   -100.1  8.36            16.76
# 2017-05-05 00:30:00   14.96             1847   -100.1  8.36            16.82
# 2017-05-05 00:45:00   14.95             1848   -100.1  8.36            17.19
# 2017-05-05 01:00:00   14.92             1848   -100.0  8.36            16.85
#
#                      ODOSat%  ODO (mg/L)  BGA-Phycocyanin RFU  \
# timestamp
# 2017-05-05 00:00:00     90.2        9.04                  0.4
# 2017-05-05 00:15:00     90.2        9.04                  0.4
# 2017-05-05 00:30:00     90.1        9.04                  0.4
# 2017-05-05 00:45:00     90.0        9.03                  0.4
# 2017-05-05 01:00:00     89.8        9.02                  0.4
#
#                                datetime
# timestamp
# 2017-05-05 00:00:00 2017-05-05 00:00:00
# 2017-05-05 00:15:00 2017-05-05 00:15:00
# 2017-05-05 00:30:00 2017-05-05 00:30:00
# 2017-05-05 00:45:00 2017-05-05 00:45:00
# 2017-05-05 01:00:00 2017-05-05 01:00:00

# %%
# Now to datetime index our 2018 data
for i in range(0, len(test_dfs)):
    timestamp = pd.to_datetime(test_dfs[i]['Time America/Boise UTC-06:00'])
    test_dfs[i]['timestamp'] = timestamp
    test_dfs[i]['datetime'] = timestamp
    test_dfs[i] = test_dfs[i].set_index('timestamp')
    test_dfs[i] = test_dfs[i].drop(columns=['Time America/Boise UTC-06:00'])
test_dfs[test_index].head()
# Out:
#                      Temp C  Sp Cond (uS/cm)  pH (mV)    pH  Turbidity (NTU)  \
# timestamp
# 2018-04-11 10:30:00   11.88             1782   -146.1  8.20            42.49
# 2018-04-11 10:45:00   11.78             1783   -143.7  8.15            42.89
# 2018-04-11 11:00:00   11.79             1784   -144.3  8.17            41.24
# 2018-04-11 11:15:00   11.66             1783   -143.1  8.14            42.65
# 2018-04-11 11:30:00   11.68             1784   -143.5  8.15            42.06
#
#                      ODOSat%  ODO (mg/L)  BGA-Phycocyanin RFU  \
# timestamp
# 2018-04-11 10:30:00     89.1        9.58                  0.6
# 2018-04-11 10:45:00     87.4        9.42                  0.6
# 2018-04-11 11:00:00     89.0        9.58                  0.7
# 2018-04-11 11:15:00     87.1        9.41                  0.7
# 2018-04-11 11:30:00     87.5        9.45                  0.7
#
#                                datetime
# timestamp
# 2018-04-11 10:30:00 2018-04-11 10:30:00
# 2018-04-11 10:45:00 2018-04-11 10:45:00
# 2018-04-11 11:00:00 2018-04-11 11:00:00
# 2018-04-11 11:15:00 2018-04-11 11:15:00
# 2018-04-11 11:30:00 2018-04-11 11:30:00

# %% [markdown]
# ## Fill missing values

# %%
# Fill all missing values with the mean
for df in test_dfs + train_dfs:
    for column in df.columns:
        number_null = np.sum(df[column].isnull())
        column_length = len(df[column])
        print('{} percent null: {:.1f}%'.format(
            column, (number_null / column_length) * 100))
        if number_null > 0:
            print("Filling {} with mean: {}\n".format(column, df[column].mean()))
            df[column] = df[column].fillna(df[column].mean())
# Out:
# Temp C percent null: 0.0%
# Sp Cond (uS/cm) percent null: 0.0%
# pH (mV) percent null: 0.0%
# pH percent null: 0.0%
# Turbidity (NTU) percent null: 0.0%
# ODOSat% percent null: 0.0%
# ODO (mg/L) percent null: 0.0%
# BGA-Phycocyanin RFU percent null: 0.0%
# datetime percent null: 0.0%
# Temp C percent null: 0.0%
# Sp Cond (uS/cm) percent null: 0.0%
# pH (mV) percent null: 0.0%
# pH percent null: 0.0%
# Turbidity (NTU) percent null: 0.0%
# ODOSat% percent null: 0.0%
# ODO (mg/L) percent null: 0.0%
# BGA-Phycocyanin RFU percent null: 0.0%
# datetime percent null: 0.0%
# Temp C percent null: 0.0%
# Sp Cond (uS/cm) percent null: 0.0%
# pH (mV) percent null: 0.0%
# pH percent null: 0.0%
# Turbidity (NTU) percent null: 0.0%
# ODOSat% percent null: 0.0%
# ODO (mg/L) percent null: 0.0%
# BGA-Phycocyanin RFU percent null: 0.0%
# datetime percent null: 0.0%
# Temp C percent null: 0.0%
# Sp Cond (uS/cm) percent null: 0.0%
# pH (mV) percent null: 0.0%
# pH percent null: 0.0%
# Turbidity (NTU) percent null: 3.2%
# Filling Turbidity (NTU) with mean: 64.96250665432234
#
# ODOSat% percent null: 0.0%
# ODO (mg/L) percent null: 0.0%
# BGA-Phycocyanin RFU percent null: 0.0%
# datetime percent null: 0.0%

# %% [markdown]
# ## Add Weather Data

# %%
## Import And Clean Weather Data
weather = pd.read_csv('../../data/cleaned/daily_weather_metric_2017_2018.csv')

# Find out how much of the data is missing for each column.
drop_columns = []
missing_threshold = .05
for column in weather.columns:
    number_null = np.sum(weather[column].isnull())
    column_length = len(weather[column])
    should_drop_column = (number_null / column_length) > missing_threshold
    print('{} percent null: {:.1f}%'.format(column, (number_null / column_length) * 100))
    if should_drop_column:
        drop_columns.append(column)
print('dropping columns: {}'.format(drop_columns))
weather = weather.drop(drop_columns, axis=1)

# Drop the columns we will not be using.
weather = weather.drop(columns=['STATION','NAME','LATITUDE','LONGITUDE','ELEVATION', 'TOBS'])

weather['DATE'] = pd.to_datetime(weather['DATE'])
# Set a datetime index for convenience
weather['timestamp'] = weather['DATE']
weather = weather.set_index('timestamp')
print(weather.dtypes)

weather['DATE'] = weather['DATE'].apply(lambda x: x.date())
# Out:
# STATION percent null: 0.0%
# NAME percent null: 0.0%
# LATITUDE percent null: 0.0%
# LONGITUDE percent null: 0.0%
# ELEVATION percent null: 0.0%
# DATE percent null: 0.0%
# DAPR percent null: 99.7%
# EVAP percent null: 50.6%
# MDPR percent null: 99.7%
# MNPN percent null: 50.9%
# MXPN percent null: 50.9%
# PRCP percent null: 0.9%
# SNOW percent null: 0.5%
# SNWD percent null: 0.5%
# TAVG percent null: 100.0%
# TMAX percent null: 0.2%
# TMIN percent null: 0.0%
# TOBS percent null: 0.5%
# WESD percent null: 100.0%
# WESF percent null: 100.0%
# WT01 percent null: 100.0%
# WT03 percent null: 99.5%
# WT04 percent null: 100.0%
# WT05 percent null: 100.0%
# WT11 percent null: 100.0%
# dropping columns: ['DAPR', 'EVAP', 'MDPR', 'MNPN', 'MXPN', 'TAVG', 'WESD', 'WESF', 'WT01', 'WT03', 'WT04', 'WT05', 'WT11']
# DATE    datetime64[ns]
# PRCP           float64
# SNOW           float64
# SNWD           float64
# TMAX           float64
# TMIN           float64
# dtype: object

# %%
# Add the weather data to our training/testing sets
count = 0
total = len(train_dfs + test_dfs)
for df in train_dfs + test_dfs:
    count += 1
    print("starting dataframe {}/{}".format(count, total))
    for column in weather.drop(columns='DATE').columns:
        print("adding series for column:", column)
        values = []
        old_datetime = None
        value = None
        for d in df['datetime']:
            d = d.date()
            if d != old_datetime:
                old_datetime = d
                value = weather[weather['DATE'] == d][column]
            values.append(value.values[0] if len(value.values) > 0 else np.nan)
        df[column] = values
# Out:
# starting dataframe 1/4
# adding series for column: PRCP
# adding series for column: SNOW
# adding series for column: SNWD
# adding series for column: TMAX
# adding series for column: TMIN
# starting dataframe 2/4
# adding series for column: PRCP
# adding series for column: SNOW
# adding series for column: SNWD
# adding series for column: TMAX
# adding series for column: TMIN
# starting dataframe 3/4
# adding series for column: PRCP
# adding series for column: SNOW
# adding series for column: SNWD
# adding series for column: TMAX
# adding series for column: TMIN
# starting dataframe 4/4
# adding series for column: PRCP
# adding series for column: SNOW
# adding series for column: SNWD
# adding series for column: TMAX
# adding series for column: TMIN

# %% [markdown]
# ## Add Date Variables

# %%
# Add month and day variables to our dataframes
for df in train_dfs + test_dfs:
    df['month'] = df['datetime'].apply(lambda x : x.month)
    df['day'] = df['datetime'].apply(
        lambda x: (x - datetime.datetime(x.year, 1,1)).days)

x_columns = list(set(x_columns + ['day','month']))
train_dfs[train_index].head()
# Out:
#                      Temp C  Sp Cond (uS/cm)  pH (mV)    pH  Turbidity (NTU)  \
# timestamp
# 2017-05-05 00:00:00   15.02             1848   -100.1  8.36            16.84
# 2017-05-05 00:15:00   14.99             1847   -100.1  8.36            16.76
# 2017-05-05 00:30:00   14.96             1847   -100.1  8.36            16.82
# 2017-05-05 00:45:00   14.95             1848   -100.1  8.36            17.19
# 2017-05-05 01:00:00   14.92             1848   -100.0  8.36            16.85
#
#                      ODOSat%  ODO (mg/L)  BGA-Phycocyanin RFU  \
# timestamp
# 2017-05-05 00:00:00     90.2        9.04                  0.4
# 2017-05-05 00:15:00     90.2        9.04                  0.4
# 2017-05-05 00:30:00     90.1        9.04                  0.4
# 2017-05-05 00:45:00     90.0        9.03                  0.4
# 2017-05-05 01:00:00     89.8        9.02                  0.4
#
#                                datetime  PRCP  SNOW  SNWD  TMAX  TMIN  month  \
# timestamp
# 2017-05-05 00:00:00 2017-05-05 00:00:00   0.0   0.0   0.0  31.7   8.9      5
# 2017-05-05 00:15:00 2017-05-05 00:15:00   0.0   0.0   0.0  31.7   8.9      5
# 2017-05-05 00:30:00 2017-05-05 00:30:00   0.0   0.0   0.0  31.7   8.9      5
# 2017-05-05 00:45:00 2017-05-05 00:45:00   0.0   0.0   0.0  31.7   8.9      5
# 2017-05-05 01:00:00 2017-05-05 01:00:00   0.0   0.0   0.0  31.7   8.9      5
#
#                      day
# timestamp
# 2017-05-05 00:00:00  124
# 2017-05-05 00:15:00  124
# 2017-05-05 00:30:00  124
# 2017-05-05 00:45:00  124
# 2017-05-05 01:00:00  124

# %% [markdown]
# ## Extract Windows

# %%
presegmented_plot = pd.DataFrame(
    {'BGA RFU': train_dfs[train_index][target_column], 
     'Bloom Threshold': np.full(train_dfs[train_index].count()[0], RFU_THRESHOLD)})

# Segment each data frame
for i in range(0, len(train_dfs)):
    print("Windowizing 2017 data set:", i)
    train_dfs[i] = hf.data_window_reduction(
        train_dfs[i], 'datetime', target_column)
    print("Windowizing 2018 data set:", i)
    test_dfs[i] = hf.data_window_reduction(
        test_dfs[i], 'datetime', target_column)
    print()
# Out:
# Windowizing 2017 data set: 0
# Segmenting...
# Extracting feature windows...
# Extracting target windows...
# Combining extractions...
# Windowizing 2018 data set: 0
# Segmenting...
# Extracting feature windows...
# Extracting target windows...
# Combining extractions...
#
# Windowizing 2017 data set: 1
# Segmenting...
# Extracting feature windows...
# Extracting target windows...
# Combining extractions...
# Windowizing 2018 data set: 1
# Segmenting...
# Extracting feature windows...
# Extracting target windows...
# Combining extractions...

# %% [markdown]
# ## Bucket/Bin Features
#
# ### Bin all numerical data

# %%
# add binned categories
bins = 4
drop_columns = []
new_columns = []
quantile_binning = False
for i in range(0, len(train_dfs)):
    train_dfs[i]
    temp = train_dfs[i][x_columns].drop(columns=drop_columns)
    binned, b_cols = hf.bin_df(temp, bins, quantile_binning)
    new_columns += b_cols
    train_dfs[i] = pd.concat([train_dfs[i], binned], axis='columns')
    
# add binned categories for testing sets
for i in range(0, len(test_dfs)):
    test_dfs[i]
    temp = test_dfs[i][x_columns].drop(columns=drop_columns)
    binned, b_cols = hf.bin_df(temp, bins, quantile_binning)
    new_columns += b_cols
    test_dfs[i] = pd.concat([test_dfs[i], binned], axis='columns')
print(test_dfs[test_index].dtypes)

# Add the new columns to x columns
x_columns = list(set(x_columns + new_columns))
print(x_columns)
# Out:
# BGA-Phycocyanin RFU              float64
# ODO (mg/L)                       float64
# ODOSat%                          float64
# PRCP                             float64
# SNOW                             float64
# SNWD                             float64
# Sp Cond (uS/cm)                  float64
# TMAX                             float64
# TMIN                             float64
# Temp C                           float64
# Turbidity (NTU)                  float64
# datetime                  datetime64[ns]
# day                              float64
# month                            float64
# pH                               float64
# pH (mV)                          float64
# ODOSat%_4_bins                  category
# Temp C_4_bins                   category
# pH (mV)_4_bins                  category
# day_4_bins                      category
# month_4_bins                    category
# pH_4_bins                       category
# Sp Cond (uS/cm)_4_bins          category
# ODO (mg/L)_4_bins               category
# Turbidity (NTU)_4_bins          category
# dtype: object
# ['ODOSat%', 'Temp C', 'day', 'pH (mV)', 'month', 'ODOSat%_4_bins', 'day_4_bins', 'Sp Cond (uS/cm)_4_bins', 'ODO (mg/L)_4_bins', 'pH', 'Turbidity (NTU)_4_bins', 'Sp Cond (uS/cm)', 'pH (mV)_4_bins', 'month_4_bins', 'pH_4_bins', 'Temp C_4_bins', 'ODO (mg/L)', 'Turbidity (NTU)']

# %% [markdown]
# ## Add Time of day Category

# %%
for df in train_dfs + test_dfs:
        df['time of day'] = df['datetime'].apply(hf.create_time_of_day).astype('category')
x_columns.append('time of day')
train_dfs[train_index].head()
# Out:
#                      BGA-Phycocyanin RFU  ODO (mg/L)  ODOSat%  PRCP  SNOW  \
# datetimeIndex
# 2017-05-06 21:36:00                0.625       9.608    97.64   1.8   0.0
# 2017-05-06 22:36:00                0.625       9.608    97.64   1.8   0.0
# 2017-05-06 23:36:00                0.625       9.608    97.64   1.8   0.0
# 2017-05-07 00:36:00                0.625       9.608    97.64   1.8   0.0
# 2017-05-07 01:36:00                0.625       9.608    97.64   1.8   0.0
#
#                      SNWD  Sp Cond (uS/cm)  TMAX  TMIN  Temp C     ...      \
# datetimeIndex                                                      ...
# 2017-05-06 21:36:00   0.0           1901.2  31.7  15.0   16.57     ...
# 2017-05-06 22:36:00   0.0           1910.4  31.7  15.0   16.57     ...
# 2017-05-06 23:36:00   0.0           1914.0  31.7  15.0   16.57     ...
# 2017-05-07 00:36:00   0.0           1914.0  31.7  18.9   16.57     ...
# 2017-05-07 01:36:00   0.0           1915.0  31.7  18.9   16.57     ...
#
#                         ODOSat%_4_bins   Temp C_4_bins     pH (mV)_4_bins  \
# datetimeIndex
# 2017-05-06 21:36:00  (76.103, 100.505]  (7.17, 12.262]  (-123.85, -115.6]
# 2017-05-06 22:36:00  (76.103, 100.505]  (7.17, 12.262]  (-123.85, -115.6]
# 2017-05-06 23:36:00  (76.103, 100.505]  (7.17, 12.262]  (-123.85, -115.6]
# 2017-05-07 00:36:00  (76.103, 100.505]  (7.17, 12.262]  (-123.85, -115.6]
# 2017-05-07 01:36:00  (76.103, 100.505]  (7.17, 12.262]  (-123.85, -115.6]
#
#                           day_4_bins  month_4_bins     pH_4_bins  \
# datetimeIndex
# 2017-05-06 21:36:00  (173.75, 222.5]   (9.5, 11.0]  (8.56, 8.75]
# 2017-05-06 22:36:00  (173.75, 222.5]   (9.5, 11.0]  (8.56, 8.75]
# 2017-05-06 23:36:00  (173.75, 222.5]   (9.5, 11.0]  (8.56, 8.75]
# 2017-05-07 00:36:00  (173.75, 222.5]   (9.5, 11.0]  (8.56, 8.75]
# 2017-05-07 01:36:00  (173.75, 222.5]   (9.5, 11.0]  (8.56, 8.75]
#
#                     Sp Cond (uS/cm)_4_bins ODO (mg/L)_4_bins  \
# datetimeIndex
# 2017-05-06 21:36:00      (1888.5, 2025.25]   (8.248, 10.097]
# 2017-05-06 22:36:00      (1888.5, 2025.25]   (8.248, 10.097]
# 2017-05-06 23:36:00      (1888.5, 2025.25]   (8.248, 10.097]
# 2017-05-07 00:36:00      (1888.5, 2025.25]   (8.248, 10.097]
# 2017-05-07 01:36:00      (1888.5, 2025.25]   (8.248, 10.097]
#
#                     Turbidity (NTU)_4_bins time of day
# datetimeIndex
# 2017-05-06 21:36:00       (14.505, 140.27]     evening
# 2017-05-06 22:36:00       (14.505, 140.27]     evening
# 2017-05-06 23:36:00       (14.505, 140.27]     evening
# 2017-05-07 00:36:00       (14.505, 140.27]        dawn
# 2017-05-07 01:36:00       (14.505, 140.27]        dawn
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Add Weather Category

# %%
# Add a rainy category
for df in test_dfs + train_dfs:
    df['rained'] = df['PRCP'].apply(
        lambda x: 1 if x > 0 else 0).astype('category')
test_dfs[test_index].columns

# add the weather columns to our x_columns
x_columns = list(set(x_columns 
                     + ['PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN', 'rained']))

# %% [markdown]
# ## BGA RFU Levels

# %%
presegmented_plot.plot.line()

# %%
pd.DataFrame({'BGA RFU': train_dfs[train_index][target_column], 
            'Bloom Threshold': np.full(
                train_dfs[train_index].count()[0], RFU_THRESHOLD)}).plot.line()

# %%
lrf.add_target_column([train_dfs[train_index], test_dfs[test_index]], 
                      threshold=RFU_THRESHOLD)

# %%
sns.lineplot(data=train_dfs[train_index][[target_column, 'bloom']], hue='bloom')

# %% [markdown]
# ## Logistic Regression Model
# ### Null Model

# %%
# The null model's performance
max_iter = 25000
loss = "log"
model = SGDClassifier(max_iter=max_iter, loss=loss)
accuracy, recall, precision, cm, _, _, _ = lrf.train_model(
    model, train_dfs[train_index], test_dfs[test_index], x_columns, 'bloom', null_model=True)
print("Accuracy", accuracy)
print("Recall:", recall)
print("Precision", precision)
print("Confusion Matrix:\n", cm)
print("columns:", train_dfs[train_index].columns)
# Out:
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
# columns: Index(['BGA-Phycocyanin RFU', 'ODO (mg/L)', 'ODOSat%', 'PRCP', 'SNOW', 'SNWD',
#        'Sp Cond (uS/cm)', 'TMAX', 'TMIN', 'Temp C', 'Turbidity (NTU)',
#        'datetime', 'day', 'month', 'pH', 'pH (mV)', 'ODOSat%_4_bins',
#        'Temp C_4_bins', 'pH (mV)_4_bins', 'day_4_bins', 'month_4_bins',
#        'pH_4_bins', 'Sp Cond (uS/cm)_4_bins', 'ODO (mg/L)_4_bins',
#        'Turbidity (NTU)_4_bins', 'time of day', 'rained', 'bloom'],
#       dtype='object')
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ### All variables model

# %%
# All variables model performance
max_iter = 25000
loss = "log"
model = SGDClassifier(max_iter=max_iter, loss=loss)
accuracy, recall, precision, cm, _, _, _ = lrf.train_model(
    model, train_dfs[train_index], test_dfs[test_index], x_columns, 'bloom')
print("Accuracy", accuracy)
print("Recall:", recall)
print("Precision", precision)
print("Confusion Matrix:\n", cm)
print("columns:", x_columns)
# Out:
# Accuracy 0.5802957717142262
# Recall: 1.0
# Precision 0.5802957717142262
# Confusion Matrix:
#  [[   0 2015]
#  [   0 2786]]
# columns: ['day', 'Temp C', 'pH (mV)', 'time of day', 'TMAX', 'Turbidity (NTU)', 'rained', 'pH', 'Sp Cond (uS/cm)', 'pH (mV)_4_bins', 'Temp C_4_bins', 'SNOW', 'PRCP', 'ODOSat%_4_bins', 'month', 'day_4_bins', 'Turbidity (NTU)_4_bins', 'TMIN', 'month_4_bins', 'pH_4_bins', 'ODOSat%', 'SNWD', 'Sp Cond (uS/cm)_4_bins', 'ODO (mg/L)_4_bins', 'ODO (mg/L)']

# %% [markdown]
# ### Best model to date

# %%
max_iter = 25000
loss = "log"
base_columns = ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)']
model = SGDClassifier(max_iter=max_iter, loss=loss)
accuracy, recall, precision, cm, _, _, _ = lrf.train_model(
    model, train_dfs[train_index], test_dfs[test_index], base_columns, 'bloom')
print("Accuracy", accuracy)
print("Recall:", recall)
print("Precision", precision)
print("Confusion Matrix:\n", cm)
print("columns:", base_columns)
# Out:
# Accuracy 0.7865028119141846
# Recall: 0.8851399856424982
# Precision 0.7776726584673604
# Confusion Matrix:
#  [[1310  705]
#  [ 320 2466]]
# columns: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)']

# %% [markdown]
# ### Greedy Model

# %%
max_iter = 25000
loss = "log"
model = SGDClassifier(max_iter=max_iter, loss=loss)
# Sort columns by accuracy
sorted_columns = lrf.sort_columns_by_metric(model, train_dfs[train_index], 
                                            test_dfs[test_index],
                                            x_columns,
                                            'bloom')
# Out:
# Training model with: day
# Accuracy 0.446990210372839
# Recall: 0.06389088298636038
# Precision 0.7911111111111111
# Confusion Matrix:
#  [[1968   47]
#  [2608  178]]
#
# Training model with: Temp C
# Accuracy 0.6059154342845241
# Recall: 0.416367552045944
# Precision 0.8134642356241234
# Confusion Matrix:
#  [[1749  266]
#  [1626 1160]]
#
# Training model with: pH (mV)
# Accuracy 0.5802957717142262
# Recall: 1.0
# Precision 0.5802957717142262
# Confusion Matrix:
#  [[   0 2015]
#  [   0 2786]]
#
# Training model with: time of day
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: TMAX
# Accuracy 0.5567590085398876
# Recall: 0.42928930366116297
# Precision 0.6897347174163783
# Confusion Matrix:
#  [[1477  538]
#  [1590 1196]]
#
# Training model with: Turbidity (NTU)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: rained
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: pH
# Accuracy 0.6854821912101645
# Recall: 0.9178033022254127
# Precision 0.6662324127149557
# Confusion Matrix:
#  [[ 734 1281]
#  [ 229 2557]]
#
# Training model with: Sp Cond (uS/cm)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: pH (mV)_4_bins
# Accuracy 0.6434076234117893
# Recall: 0.45908111988514
# Precision 0.8618598382749326
# Confusion Matrix:
#  [[1810  205]
#  [1507 1279]]
#
# Training model with: Temp C_4_bins
# Accuracy 0.6034159550093731
# Recall: 0.4335965541995693
# Precision 0.78748370273794
# Confusion Matrix:
#  [[1689  326]
#  [1578 1208]]
#
# Training model with: SNOW
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: PRCP
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: ODOSat%_4_bins
# Accuracy 0.7156842324515726
# Recall: 0.7135678391959799
# Precision 0.7780821917808219
# Confusion Matrix:
#  [[1448  567]
#  [ 798 1988]]
#
# Training model with: month
# Accuracy 0.44157467194334515
# Recall: 0.1453697056712132
# Precision 0.574468085106383
# Confusion Matrix:
#  [[1715  300]
#  [2381  405]]
#
# Training model with: day_4_bins
# Accuracy 0.6292439075192668
# Recall: 0.6112706389088298
# Precision 0.7095833333333333
# Confusion Matrix:
#  [[1318  697]
#  [1083 1703]]
#
# Training model with: Turbidity (NTU)_4_bins
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: TMIN
# Accuracy 0.6702770256196626
# Recall: 0.5337401292175161
# Precision 0.8396386222473179
# Confusion Matrix:
#  [[1731  284]
#  [1299 1487]]
#
# Training model with: month_4_bins
# Accuracy 0.5692564049156426
# Recall: 0.5251256281407035
# Precision 0.6625905797101449
# Confusion Matrix:
#  [[1270  745]
#  [1323 1463]]
#
# Training model with: pH_4_bins
# Accuracy 0.757550510310352
# Recall: 0.7616654702081838
# Precision 0.8093058733790999
# Confusion Matrix:
#  [[1515  500]
#  [ 664 2122]]
#
# Training model with: ODOSat%
# Accuracy 0.7167256821495521
# Recall: 0.6920315865039484
# Precision 0.7934156378600823
# Confusion Matrix:
#  [[1513  502]
#  [ 858 1928]]
#
# Training model with: SNWD
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: Sp Cond (uS/cm)_4_bins
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: ODO (mg/L)_4_bins
# Accuracy 0.6192459904186628
# Recall: 0.38190954773869346
# Precision 0.9094017094017094
# Confusion Matrix:
#  [[1909  106]
#  [1722 1064]]
#
# Training model with: ODO (mg/L)
# Accuracy 0.7042282857737971
# Recall: 0.6826992103374013
# Precision 0.7801476620180475
# Confusion Matrix:
#  [[1479  536]
#  [ 884 1902]]
#
# pH_4_bins metric value: 0.757550510310352
# ODOSat% metric value: 0.7167256821495521
# ODOSat%_4_bins metric value: 0.7156842324515726
# ODO (mg/L) metric value: 0.7042282857737971
# pH metric value: 0.6854821912101645
# TMIN metric value: 0.6702770256196626
# pH (mV)_4_bins metric value: 0.6434076234117893
# day_4_bins metric value: 0.6292439075192668
# ODO (mg/L)_4_bins metric value: 0.6192459904186628
# Temp C metric value: 0.6059154342845241
# Temp C_4_bins metric value: 0.6034159550093731
# pH (mV) metric value: 0.5802957717142262
# month_4_bins metric value: 0.5692564049156426
# TMAX metric value: 0.5567590085398876
# day metric value: 0.446990210372839
# month metric value: 0.44157467194334515
# time of day metric value: 0.4197042282857738
# Turbidity (NTU) metric value: 0.4197042282857738
# rained metric value: 0.4197042282857738
# Sp Cond (uS/cm) metric value: 0.4197042282857738
# SNOW metric value: 0.4197042282857738
# PRCP metric value: 0.4197042282857738
# Turbidity (NTU)_4_bins metric value: 0.4197042282857738
# SNWD metric value: 0.4197042282857738
# Sp Cond (uS/cm)_4_bins metric value: 0.4197042282857738

# %%
#create greedy model
model = SGDClassifier(max_iter=max_iter, loss=loss)

accuracy, recall, precision, cm, predictions, predictions_prob, model = lrf.greedy_model(
    model, train_dfs[train_index], test_dfs[test_index], x_columns, 
                                            'bloom', sorted_columns)
# Out:
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# greedy_columns: []
# sorted_columns: ['pH_4_bins', 'ODOSat%', 'ODOSat%_4_bins', 'ODO (mg/L)', 'pH', 'TMIN', 'pH (mV)_4_bins', 'day_4_bins', 'ODO (mg/L)_4_bins', 'Temp C', 'Temp C_4_bins', 'pH (mV)', 'month_4_bins', 'TMAX', 'day', 'month', 'time of day', 'Turbidity (NTU)', 'rained', 'Sp Cond (uS/cm)', 'SNOW', 'PRCP', 'Turbidity (NTU)_4_bins', 'SNWD', 'Sp Cond (uS/cm)_4_bins']
# adjusted sorted_columns: ['pH_4_bins', 'ODOSat%', 'ODOSat%_4_bins', 'ODO (mg/L)', 'pH', 'TMIN', 'pH (mV)_4_bins', 'day_4_bins', 'ODO (mg/L)_4_bins', 'Temp C', 'Temp C_4_bins', 'pH (mV)', 'month_4_bins', 'TMAX', 'day', 'month', 'time of day', 'Turbidity (NTU)', 'rained', 'Sp Cond (uS/cm)', 'SNOW', 'PRCP', 'Turbidity (NTU)_4_bins', 'SNWD', 'Sp Cond (uS/cm)_4_bins']
# Training model with: ['pH_4_bins']
# Test model accuracy: 0.757550510310352
# Test model recall: 0.7616654702081838
# Test model precision: 0.8093058733790999
#
# Updating greedy model
#
# Training model with: ['pH_4_bins', 'ODOSat%']
# Test model accuracy: 0.7363049364715685
# Test model recall: 0.7214644651830582
# Test model precision: 0.804
#
# Training model with: ['pH_4_bins', 'ODOSat%_4_bins']
# Test model accuracy: 0.7242241199750052
# Test model recall: 0.6486001435750179
# Test model precision: 0.8396840148698885
#
# Training model with: ['pH_4_bins', 'ODO (mg/L)']
# Test model accuracy: 0.7554676109143929
# Test model recall: 0.7562814070351759
# Test model precision: 0.809761721752498
#
# Training model with: ['pH_4_bins', 'pH']
# Test model accuracy: 0.6858987710893564
# Test model recall: 0.9178033022254127
# Test model precision: 0.6665797705943691
#
# Training model with: ['pH_4_bins', 'TMIN']
# Test model accuracy: 0.757550510310352
# Test model recall: 0.7616654702081838
# Test model precision: 0.8093058733790999
#
# Training model with: ['pH_4_bins', 'pH (mV)_4_bins']
# Test model accuracy: 0.757550510310352
# Test model recall: 0.7616654702081838
# Test model precision: 0.8093058733790999
#
# Training model with: ['pH_4_bins', 'day_4_bins']
# Test model accuracy: 0.7637992084982296
# Test model recall: 0.7598707824838478
# Test model precision: 0.8199070487993804
#
# Updating greedy model
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'ODO (mg/L)_4_bins']
# Test model accuracy: 0.7238075400958134
# Test model recall: 0.6823402727925341
# Test model precision: 0.8116994022203246
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'Temp C']
# Test model accuracy: 0.7637992084982296
# Test model recall: 0.7598707824838478
# Test model precision: 0.8199070487993804
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'Temp C_4_bins']
# Test model accuracy: 0.7285982087065195
# Test model recall: 0.8169418521177315
# Test model precision: 0.7416096448354513
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'pH (mV)']
# Test model accuracy: 0.7142262028744012
# Test model recall: 0.9055994256999282
# Test model precision: 0.6946585903083701
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'month_4_bins']
# Test model accuracy: 0.7637992084982296
# Test model recall: 0.7598707824838478
# Test model precision: 0.8199070487993804
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX']
# Test model accuracy: 0.772547385961258
# Test model recall: 0.7749461593682699
# Test model precision: 0.8227896341463414
#
# Updating greedy model
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'day']
# Test model accuracy: 0.7446365340554051
# Test model recall: 0.7763819095477387
# Test model precision: 0.7819956616052061
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'month']
# Test model accuracy: 0.772547385961258
# Test model recall: 0.7749461593682699
# Test model precision: 0.8227896341463414
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'time of day']
# Test model accuracy: 0.7733805457196418
# Test model recall: 0.7763819095477387
# Test model precision: 0.8230593607305936
#
# Updating greedy model
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'time of day', 'Turbidity (NTU)']
# Test model accuracy: 0.7733805457196418
# Test model recall: 0.7763819095477387
# Test model precision: 0.8230593607305936
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'time of day', 'rained']
# Test model accuracy: 0.772547385961258
# Test model recall: 0.7749461593682699
# Test model precision: 0.8227896341463414
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'time of day', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.7733805457196418
# Test model recall: 0.7763819095477387
# Test model precision: 0.8230593607305936
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'time of day', 'SNOW']
# Test model accuracy: 0.7733805457196418
# Test model recall: 0.7763819095477387
# Test model precision: 0.8230593607305936
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'time of day', 'PRCP']
# Test model accuracy: 0.7652572380754009
# Test model recall: 0.7598707824838478
# Test model precision: 0.8221359223300971
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'time of day', 'Turbidity (NTU)_4_bins']
# Test model accuracy: 0.7648406581962092
# Test model recall: 0.7616654702081838
# Test model precision: 0.8202551217626595
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'time of day', 'SNWD']
# Test model accuracy: 0.7733805457196418
# Test model recall: 0.7763819095477387
# Test model precision: 0.8230593607305936
#
# Training model with: ['pH_4_bins', 'day_4_bins', 'TMAX', 'time of day', 'Sp Cond (uS/cm)_4_bins']
# Test model accuracy: 0.7779629243907519
# Test model recall: 0.7770997846374731
# Test model precision: 0.8295019157088123
#
# Updating greedy model
#
# Final greedy columns: ['pH_4_bins', 'day_4_bins', 'TMAX', 'time of day', 'Sp Cond (uS/cm)_4_bins']
# Final greedy accuracy 0.7779629243907519
# Final greedy recall: 0.7770997846374731
# Final greedy precision: 0.8295019157088123
# Final greedy confusion matrix:
#  [[1570  445]
#  [ 621 2165]]

# %%
# Print the ROC curve.
predictions = [x[1] for x in predictions_prob]
lrf.roc_plot(test_dfs[test_index][['bloom']].values, predictions)
# Out:
# Model AUC: 0.8170

# %% [markdown]
# ### Greedy Model With Base Columns

# %%
#create greedy model
model = SGDClassifier(max_iter=max_iter, loss=loss)

accuracy, recall, precision, cm, predictions, predictions_prob, model = lrf.greedy_model(
    model, train_dfs[train_index], test_dfs[test_index], x_columns, 
                                            'bloom', sorted_columns, base_columns)
# Out:
# greedy_columns: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)']
# sorted_columns: ['pH_4_bins', 'ODOSat%', 'ODOSat%_4_bins', 'ODO (mg/L)', 'pH', 'TMIN', 'pH (mV)_4_bins', 'day_4_bins', 'ODO (mg/L)_4_bins', 'Temp C', 'Temp C_4_bins', 'pH (mV)', 'month_4_bins', 'TMAX', 'day', 'month', 'time of day', 'Turbidity (NTU)', 'rained', 'Sp Cond (uS/cm)', 'SNOW', 'PRCP', 'Turbidity (NTU)_4_bins', 'SNWD', 'Sp Cond (uS/cm)_4_bins']
# adjusted sorted_columns: ['pH_4_bins', 'ODOSat%_4_bins', 'TMIN', 'pH (mV)_4_bins', 'day_4_bins', 'ODO (mg/L)_4_bins', 'Temp C_4_bins', 'pH (mV)', 'month_4_bins', 'TMAX', 'day', 'month', 'time of day', 'Turbidity (NTU)', 'rained', 'SNOW', 'PRCP', 'Turbidity (NTU)_4_bins', 'SNWD', 'Sp Cond (uS/cm)_4_bins']
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'pH_4_bins']
# Test model accuracy: 0.7860862320349927
# Test model recall: 0.8916008614501076
# Test model precision: 0.7740729199127454
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'ODOSat%_4_bins']
# Test model accuracy: 0.7758800249947928
# Test model recall: 0.8797559224694903
# Test model precision: 0.7678571428571429
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN']
# Test model accuracy: 0.8031660070818579
# Test model recall: 0.8833452979181622
# Test model precision: 0.7987666342096722
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'pH (mV)_4_bins']
# Test model accuracy: 0.800458237867111
# Test model recall: 0.8804737975592247
# Test model precision: 0.7969460688758935
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'day_4_bins']
# Test model accuracy: 0.7531764215788378
# Test model recall: 0.6920315865039484
# Test model precision: 0.8549889135254989
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'ODO (mg/L)_4_bins']
# Test model accuracy: 0.7958758591960008
# Test model recall: 0.8894472361809045
# Test model precision: 0.7866666666666666
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'Temp C_4_bins']
# Test model accuracy: 0.7910851905852947
# Test model recall: 0.8840631730078966
# Test model precision: 0.7836461979000955
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'pH (mV)']
# Test model accuracy: 0.5873776296604873
# Test model recall: 1.0
# Test model precision: 0.5844346549192364
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins']
# Test model accuracy: 0.820662362007915
# Test model recall: 0.8478104809763102
# Test model precision: 0.8438728117184708
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'TMAX']
# Test model accuracy: 0.820662362007915
# Test model recall: 0.8478104809763102
# Test model precision: 0.8438728117184708
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'day']
# Test model accuracy: 0.8146219537596334
# Test model recall: 0.8801148600143575
# Test model precision: 0.8151595744680851
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'month']
# Test model accuracy: 0.8139970839408457
# Test model recall: 0.7896625987078248
# Test model precision: 0.8775428799361787
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'time of day']
# Test model accuracy: 0.8204540720683191
# Test model recall: 0.8488872936109118
# Test model precision: 0.8428367783321454
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'Turbidity (NTU)']
# Test model accuracy: 0.8175380129139762
# Test model recall: 0.8431442928930366
# Test model precision: 0.8425394548063128
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'rained']
# Test model accuracy: 0.820870651947511
# Test model recall: 0.8413496051687006
# Test model precision: 0.8486603910209993
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'rained', 'SNOW']
# Test model accuracy: 0.820870651947511
# Test model recall: 0.8413496051687006
# Test model precision: 0.8486603910209993
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'rained', 'PRCP']
# Test model accuracy: 0.8210789418871068
# Test model recall: 0.8417085427135679
# Test model precision: 0.8487151646760768
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'rained', 'PRCP', 'Turbidity (NTU)_4_bins']
# Test model accuracy: 0.8189960424911477
# Test model recall: 0.8374012921751616
# Test model precision: 0.8486722444525282
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'rained', 'PRCP', 'SNWD']
# Test model accuracy: 0.8210789418871068
# Test model recall: 0.8417085427135679
# Test model precision: 0.8487151646760768
#
# Training model with: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'rained', 'PRCP', 'Sp Cond (uS/cm)_4_bins']
# Test model accuracy: 0.8171214330347845
# Test model recall: 0.8108399138549892
# Test model precision: 0.8655172413793103
#
# Final greedy columns: ['ODOSat%', 'ODO (mg/L)', 'pH', 'Temp C', 'Sp Cond (uS/cm)', 'TMIN', 'month_4_bins', 'rained', 'PRCP']
# Final greedy accuracy 0.8210789418871068
# Final greedy recall: 0.8417085427135679
# Final greedy precision: 0.8487151646760768
# Final greedy confusion matrix:
#  [[1597  418]
#  [ 441 2345]]

# %% [markdown]
# ## Random Forest Model

# %%
# All Inputs
model = RandomForestClassifier(n_estimators=100)
accuracy, recall, precision, cm, predictions, predictions_prob, model = lrf.train_model(
    model, train_dfs[train_index], test_dfs[test_index], x_columns, 'bloom')
print("Accuracy", accuracy)
print("Recall:", recall)
print("Precision", precision)
print("Confusion Matrix:\n", cm)
# Out:
# Accuracy 0.7715059362632785
# Recall: 0.7440775305096913
# Precision 0.8437118437118437
# Confusion Matrix:
#  [[1631  384]
#  [ 713 2073]]

# %%
# Print the ROC curve.
predictions = [x[1] for x in predictions_prob]
lrf.roc_plot(test_dfs[test_index][['bloom']].values, predictions)
# Out:
# Model AUC: 0.8366

# %% [markdown]
# ### Greedy model with Squaring Features

# %%
model = SGDClassifier(max_iter=max_iter, loss=loss)
# Sort columns by accuracy
sorted_columns = lrf.sort_columns_by_metric(model, train_dfs[train_index], 
                                            test_dfs[test_index],
                                            x_columns,
                                            'bloom', mathop=math_operation)
# Out:
# Training model with: day
# Accuracy 0.7825453030618621
# Recall: 0.6658291457286433
# Precision 0.9425813008130082
# Confusion Matrix:
#  [[1902  113]
#  [ 931 1855]]
#
# Training model with: Temp C
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: pH (mV)
# Accuracy 0.5802957717142262
# Recall: 1.0
# Precision 0.5802957717142262
# Confusion Matrix:
#  [[   0 2015]
#  [   0 2786]]
#
# Training model with: time of day
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: TMAX
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: Turbidity (NTU)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: rained
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: pH
# Accuracy 0.770256196625703
# Recall: 0.873653984206748
# Precision 0.7642072213500785
# Confusion Matrix:
#  [[1264  751]
#  [ 352 2434]]
#
# Training model with: Sp Cond (uS/cm)
# Accuracy 0.4780254113726307
# Recall: 0.17767408470926058
# Precision 0.6971830985915493
# Confusion Matrix:
#  [[1800  215]
#  [2291  495]]
#
# Training model with: pH (mV)_4_bins
# Accuracy 0.6434076234117893
# Recall: 0.45908111988514
# Precision 0.8618598382749326
# Confusion Matrix:
#  [[1810  205]
#  [1507 1279]]
#
# Training model with: Temp C_4_bins
# Accuracy 0.6034159550093731
# Recall: 0.4335965541995693
# Precision 0.78748370273794
# Confusion Matrix:
#  [[1689  326]
#  [1578 1208]]
#
# Training model with: SNOW
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: PRCP
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: ODOSat%_4_bins
# Accuracy 0.7156842324515726
# Recall: 0.7135678391959799
# Precision 0.7780821917808219
# Confusion Matrix:
#  [[1448  567]
#  [ 798 1988]]
#
# Training model with: month
# Accuracy 0.8100395750885232
# Recall: 0.7325915290739411
# Precision 0.9243659420289855
# Confusion Matrix:
#  [[1848  167]
#  [ 745 2041]]
#
# Training model with: day_4_bins
# Accuracy 0.6292439075192668
# Recall: 0.6112706389088298
# Precision 0.7095833333333333
# Confusion Matrix:
#  [[1318  697]
#  [1083 1703]]
#
# Training model with: Turbidity (NTU)_4_bins
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: TMIN
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: month_4_bins
# Accuracy 0.5692564049156426
# Recall: 0.5251256281407035
# Precision 0.6625905797101449
# Confusion Matrix:
#  [[1270  745]
#  [1323 1463]]
#
# Training model with: pH_4_bins
# Accuracy 0.757550510310352
# Recall: 0.7616654702081838
# Precision 0.8093058733790999
# Confusion Matrix:
#  [[1515  500]
#  [ 664 2122]]
#
# Training model with: ODOSat%
# Accuracy 0.6304936471568423
# Recall: 0.4619526202440775
# Precision 0.823943661971831
# Confusion Matrix:
#  [[1740  275]
#  [1499 1287]]
#
# Training model with: SNWD
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: Sp Cond (uS/cm)_4_bins
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Accuracy 0.4197042282857738
# Recall: 0.0
# Precision 0.0
# Confusion Matrix:
#  [[2015    0]
#  [2786    0]]
#
# Training model with: ODO (mg/L)_4_bins
# Accuracy 0.6192459904186628
# Recall: 0.38190954773869346
# Precision 0.9094017094017094
# Confusion Matrix:
#  [[1909  106]
#  [1722 1064]]
#
# Training model with: ODO (mg/L)
# Accuracy 0.6154967715059363
# Recall: 0.38334529791816224
# Precision 0.8929765886287625
# Confusion Matrix:
#  [[1887  128]
#  [1718 1068]]
#
# month metric value: 0.8100395750885232
# day metric value: 0.7825453030618621
# pH metric value: 0.770256196625703
# pH_4_bins metric value: 0.757550510310352
# ODOSat%_4_bins metric value: 0.7156842324515726
# pH (mV)_4_bins metric value: 0.6434076234117893
# ODOSat% metric value: 0.6304936471568423
# day_4_bins metric value: 0.6292439075192668
# ODO (mg/L)_4_bins metric value: 0.6192459904186628
# ODO (mg/L) metric value: 0.6154967715059363
# Temp C_4_bins metric value: 0.6034159550093731
# pH (mV) metric value: 0.5802957717142262
# month_4_bins metric value: 0.5692564049156426
# Sp Cond (uS/cm) metric value: 0.4780254113726307
# Temp C metric value: 0.4197042282857738
# time of day metric value: 0.4197042282857738
# TMAX metric value: 0.4197042282857738
# Turbidity (NTU) metric value: 0.4197042282857738
# rained metric value: 0.4197042282857738
# SNOW metric value: 0.4197042282857738
# PRCP metric value: 0.4197042282857738
# Turbidity (NTU)_4_bins metric value: 0.4197042282857738
# TMIN metric value: 0.4197042282857738
# SNWD metric value: 0.4197042282857738
# Sp Cond (uS/cm)_4_bins metric value: 0.4197042282857738

# %%
#create greedy model
model = SGDClassifier(max_iter=max_iter, loss=loss)

accuracy, recall, precision, cm, predictions, predictions_prob, model = lrf.greedy_model(
    model, train_dfs[train_index], test_dfs[test_index], x_columns, 
                                            'bloom', sorted_columns, mathop=math_operation)
# Out:
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# greedy_columns: []
# sorted_columns: ['month', 'day', 'pH', 'pH_4_bins', 'ODOSat%_4_bins', 'pH (mV)_4_bins', 'ODOSat%', 'day_4_bins', 'ODO (mg/L)_4_bins', 'ODO (mg/L)', 'Temp C_4_bins', 'pH (mV)', 'month_4_bins', 'Sp Cond (uS/cm)', 'Temp C', 'time of day', 'TMAX', 'Turbidity (NTU)', 'rained', 'SNOW', 'PRCP', 'Turbidity (NTU)_4_bins', 'TMIN', 'SNWD', 'Sp Cond (uS/cm)_4_bins']
# adjusted sorted_columns: ['month', 'day', 'pH', 'pH_4_bins', 'ODOSat%_4_bins', 'pH (mV)_4_bins', 'ODOSat%', 'day_4_bins', 'ODO (mg/L)_4_bins', 'ODO (mg/L)', 'Temp C_4_bins', 'pH (mV)', 'month_4_bins', 'Sp Cond (uS/cm)', 'Temp C', 'time of day', 'TMAX', 'Turbidity (NTU)', 'rained', 'SNOW', 'PRCP', 'Turbidity (NTU)_4_bins', 'TMIN', 'SNWD', 'Sp Cond (uS/cm)_4_bins']
# Training model with: ['month']
# Test model accuracy: 0.8100395750885232
# Test model recall: 0.7325915290739411
# Test model precision: 0.9243659420289855
#
# Updating greedy model
#
# Training model with: ['month', 'day']
# Test model accuracy: 0.7729639658404499
# Test model recall: 0.6489590811198851
# Test model precision: 0.9416666666666667
#
# Training model with: ['month', 'pH']
# Test model accuracy: 0.8014996875650906
# Test model recall: 0.8607322325915291
# Test model precision: 0.8093148835639554
#
# Training model with: ['month', 'pH_4_bins']
# Test model accuracy: 0.757550510310352
# Test model recall: 0.7616654702081838
# Test model precision: 0.8093058733790999
#
# Training model with: ['month', 'ODOSat%_4_bins']
# Test model accuracy: 0.7156842324515726
# Test model recall: 0.7135678391959799
# Test model precision: 0.7780821917808219
#
# Training model with: ['month', 'pH (mV)_4_bins']
# Test model accuracy: 0.6196625702978547
# Test model recall: 0.375448671931084
# Test model precision: 0.9240282685512368
#
# Training model with: ['month', 'ODOSat%']
# Test model accuracy: 0.6673609664653197
# Test model recall: 0.5003589375448672
# Test model precision: 0.8717948717948718
#
# Training model with: ['month', 'day_4_bins']
# Test model accuracy: 0.6292439075192668
# Test model recall: 0.6112706389088298
# Test model precision: 0.7095833333333333
#
# Training model with: ['month', 'ODO (mg/L)_4_bins']
# Test model accuracy: 0.7329722974380337
# Test model recall: 0.5807609475951184
# Test model precision: 0.9341801385681293
#
# Training model with: ['month', 'ODO (mg/L)']
# Test model accuracy: 0.7131847531764216
# Test model recall: 0.5466618808327351
# Test model precision: 0.9303604153940135
#
# Training model with: ['month', 'Temp C_4_bins']
# Test model accuracy: 0.6519475109352219
# Test model recall: 0.4314429289303661
# Test model precision: 0.9325058184639256
#
# Training model with: ['month', 'pH (mV)']
# Test model accuracy: 0.5886273692980629
# Test model recall: 0.9946159368269921
# Test model precision: 0.5857112661171
#
# Training model with: ['month', 'month_4_bins']
# Test model accuracy: 0.5692564049156426
# Test model recall: 0.5251256281407035
# Test model precision: 0.6625905797101449
#
# Training model with: ['month', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.712143303478442
# Test model recall: 0.5387652548456568
# Test model precision: 0.9392991239048811
#
# Training model with: ['month', 'Temp C']
# Test model accuracy: 0.6704853155592585
# Test model recall: 0.48133524766690594
# Test model precision: 0.9073071718538566
#
# Training model with: ['month', 'time of day']
# Test model accuracy: 0.8100395750885232
# Test model recall: 0.7325915290739411
# Test model precision: 0.9243659420289855
#
# Training model with: ['month', 'TMAX']
# Test model accuracy: 0.6961049781295563
# Test model recall: 0.5416367552045944
# Test model precision: 0.8923713778829095
#
# Training model with: ['month', 'Turbidity (NTU)']
# Test model accuracy: 0.7735888356592376
# Test model recall: 0.6697774587221823
# Test model precision: 0.9178553861288736
#
# Training model with: ['month', 'rained']
# Test model accuracy: 0.8100395750885232
# Test model recall: 0.7325915290739411
# Test model precision: 0.9243659420289855
#
# Training model with: ['month', 'SNOW']
# Test model accuracy: 0.8100395750885232
# Test model recall: 0.7325915290739411
# Test model precision: 0.9243659420289855
#
# Training model with: ['month', 'PRCP']
# Test model accuracy: 0.8100395750885232
# Test model recall: 0.7325915290739411
# Test model precision: 0.9243659420289855
#
# Training model with: ['month', 'Turbidity (NTU)_4_bins']
# Test model accuracy: 0.8014996875650906
# Test model recall: 0.7178750897343862
# Test model precision: 0.9229349330872173
#
# Training model with: ['month', 'TMIN']
# Test model accuracy: 0.8100395750885232
# Test model recall: 0.7325915290739411
# Test model precision: 0.9243659420289855
#
# Training model with: ['month', 'SNWD']
# Test model accuracy: 0.8100395750885232
# Test model recall: 0.7325915290739411
# Test model precision: 0.9243659420289855
#
# Training model with: ['month', 'Sp Cond (uS/cm)_4_bins']
# Test model accuracy: 0.8100395750885232
# Test model recall: 0.7325915290739411
# Test model precision: 0.9243659420289855
#
# Final greedy columns: ['month']
# Final greedy accuracy 0.8100395750885232
# Final greedy recall: 0.7325915290739411
# Final greedy precision: 0.9243659420289855
# Final greedy confusion matrix:
#  [[1848  167]
#  [ 745 2041]]
