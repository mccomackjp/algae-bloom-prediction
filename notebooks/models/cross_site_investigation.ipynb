# %% [markdown]
# # Logistic Regression Model

# %% [markdown]
# ## Data Import And Cleaning

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import datetime
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import recall_score, precision_score, confusion_matrix
from sklearn.metrics import roc_curve, auc
import scripts.logistic_regression_functions as lrf
import scripts.helper_functions as hf
from functools import partial

#reloads the module with the most recent updates
# %load_ext autoreload
# %aimport scripts.logistic_regression_functions, scripts.helper_functions
# %autoreload 2
# Out:
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_files = ['../../data/cleaned/utah_2017_vineyard.csv', 
               '../../data/cleaned/utah_2017_marina.csv']

test_files = ['../../data/cleaned/utah_2018_marina.csv',
               '../../data/cleaned/utah_2018_bird.csv']

drop_columns = ['Chlorophyll ug/L', 'Chlorophyll RFU', 'Wiper Pos V',
                'Cable Pwr V', 'Battery V', 'Chlorophyll (ug/L)', 'FDOM RFU']

x_columns = ['Temp C', 'Sp Cond (uS/cm)', 'pH (mV)', 'pH', 'Turbidity (NTU)',
            'ODOSat%', 'ODO (mg/L)']

target_column = 'BGA-Phycocyanin RFU'

# TODO Create average off of minor bloom
RFU_THRESHOLD = 1.2
train_index = 0
test_index = 0
#the operation to be used for math operations during training.
math_operation = partial(np.square)

# %%
# Load the data
train_dfs = lrf.import_df_data(train_files, drop_columns)
test_dfs = lrf.import_df_data(test_files, drop_columns)

train_dfs[train_index].head()
# Out:
#   Date (mm.dd.yyyy) Time 24hr  Temp C  Sp Cond (uS/cm)  pH (mV)    pH  \
# 0          5/5/2017      0:00   15.02             1848   -100.1  8.36
# 1          5/5/2017      0:15   14.99             1847   -100.1  8.36
# 2          5/5/2017      0:30   14.96             1847   -100.1  8.36
# 3          5/5/2017      0:45   14.95             1848   -100.1  8.36
# 4          5/5/2017      1:00   14.92             1848   -100.0  8.36
#
#    Turbidity (NTU)  ODOSat%  ODO (mg/L)  BGA-Phycocyanin RFU
# 0            16.84     90.2        9.04                  0.4
# 1            16.76     90.2        9.04                  0.4
# 2            16.82     90.1        9.04                  0.4
# 3            17.19     90.0        9.03                  0.4
# 4            16.85     89.8        9.02                  0.4

# %%
test_dfs[test_index].head()
# Out:
#   Time America/Boise UTC-06:00  Temp C  Sp Cond (uS/cm)  pH (mV)    pH  \
# 0              4/11/2018 10:30   11.88             1782   -146.1  8.20
# 1              4/11/2018 10:45   11.78             1783   -143.7  8.15
# 2              4/11/2018 11:00   11.79             1784   -144.3  8.17
# 3              4/11/2018 11:15   11.66             1783   -143.1  8.14
# 4              4/11/2018 11:30   11.68             1784   -143.5  8.15
#
#    Turbidity (NTU)  ODOSat%  ODO (mg/L)  BGA-Phycocyanin RFU
# 0            42.49     89.1        9.58                  0.6
# 1            42.89     87.4        9.42                  0.6
# 2            41.24     89.0        9.58                  0.7
# 3            42.65     87.1        9.41                  0.7
# 4            42.06     87.5        9.45                  0.7

# %%
train_dfs[train_index].describe()
# Out:
#              Temp C  Sp Cond (uS/cm)       pH (mV)            pH  \
# count  18947.000000     18947.000000  18947.000000  18947.000000
# mean      18.488235      1933.564575   -116.806951      8.633415
# std        6.134464       151.800551      8.973830      0.147231
# min        5.630000         3.000000   -153.700000      7.930000
# 25%       12.700000      1848.000000   -120.800000      8.530000
# 50%       20.320000      1939.000000   -115.700000      8.650000
# 75%       23.630000      2070.000000   -112.100000      8.700000
# max       28.570000      2164.000000    -76.500000      9.230000
#
#        Turbidity (NTU)       ODOSat%    ODO (mg/L)  BGA-Phycocyanin RFU
# count     18947.000000  18947.000000  18947.000000         18947.000000
# mean         58.129348     87.056980      8.179008             0.979511
# std          54.622278     13.793755      1.278416             0.731423
# min           0.660000     62.800000      5.170000             0.000000
# 25%          29.850000     80.000000      7.260000             0.500000
# 50%          42.140000     83.200000      8.080000             0.900000
# 75%          65.795000     88.900000      9.250000             1.200000
# max         636.700000    209.700000     16.170000            16.100000

# %%
train_dfs[train_index][[target_column]].describe()
# Out:
#        BGA-Phycocyanin RFU
# count         18947.000000
# mean              0.979511
# std               0.731423
# min               0.000000
# 25%               0.500000
# 50%               0.900000
# 75%               1.200000
# max              16.100000

# %%
test_dfs[test_index].describe()
# Out:
#              Temp C  Sp Cond (uS/cm)       pH (mV)            pH  \
# count  19487.000000     19487.000000  19487.000000  19487.000000
# mean      19.131184      1990.294607   -196.624329      8.922357
# std        5.045367       230.743946     27.769024      0.357733
# min        0.000000         0.000000   -284.000000      0.000000
# 25%       15.480000      1869.000000   -216.950000      8.730000
# 50%       20.190000      1958.000000   -192.000000      8.920000
# 75%       23.070000      2149.000000   -179.500000      9.100000
# max       28.600000      2417.000000      0.000000     10.100000
#
#        Turbidity (NTU)       ODOSat%    ODO (mg/L)  BGA-Phycocyanin RFU
# count     19487.000000  19487.000000  19487.000000         19487.000000
# mean         63.929067     90.057202      8.309566             1.459773
# std          70.885989     17.627283      1.486747             1.311960
# min          -0.880000      0.000000      0.000000            -0.400000
# 25%          33.750000     79.100000      7.280000             0.600000
# 50%          48.380000     85.300000      8.010000             1.000000
# 75%          68.275000     95.300000      9.240000             1.700000
# max        1248.920000    245.500000     19.590000            21.100000

# %% [markdown]
# ## Use Datetime Index

# %%
print(test_dfs[test_index].dtypes)
print(train_dfs[train_index].dtypes)
# Out:
# Time America/Boise UTC-06:00     object
# Temp C                          float64
# Sp Cond (uS/cm)                   int64
# pH (mV)                         float64
# pH                              float64
# Turbidity (NTU)                 float64
# ODOSat%                         float64
# ODO (mg/L)                      float64
# BGA-Phycocyanin RFU             float64
# dtype: object
# Date (mm.dd.yyyy)       object
# Time 24hr               object
# Temp C                 float64
# Sp Cond (uS/cm)          int64
# pH (mV)                float64
# pH                     float64
# Turbidity (NTU)        float64
# ODOSat%                float64
# ODO (mg/L)             float64
# BGA-Phycocyanin RFU    float64
# dtype: object

# %%
# We will need to engineer a datetime column for our 2017 data

# Create a single datetime column from the strings provided in our csv's
for i in range(0, len(train_dfs)):
    timestamp = train_dfs[i]['Date (mm.dd.yyyy)'] + ' '+ train_dfs[i]['Time 24hr']
    timestamp = pd.to_datetime(timestamp)
    train_dfs[i]['timestamp'] = timestamp
    train_dfs[i]['datetime'] = timestamp
    train_dfs[i] = train_dfs[i].set_index('timestamp')
    train_dfs[i] = train_dfs[i].drop(columns=['Date (mm.dd.yyyy)', 'Time 24hr'])
train_dfs[train_index].head()
# Out:
#                      Temp C  Sp Cond (uS/cm)  pH (mV)    pH  Turbidity (NTU)  \
# timestamp
# 2017-05-05 00:00:00   15.02             1848   -100.1  8.36            16.84
# 2017-05-05 00:15:00   14.99             1847   -100.1  8.36            16.76
# 2017-05-05 00:30:00   14.96             1847   -100.1  8.36            16.82
# 2017-05-05 00:45:00   14.95             1848   -100.1  8.36            17.19
# 2017-05-05 01:00:00   14.92             1848   -100.0  8.36            16.85
#
#                      ODOSat%  ODO (mg/L)  BGA-Phycocyanin RFU  \
# timestamp
# 2017-05-05 00:00:00     90.2        9.04                  0.4
# 2017-05-05 00:15:00     90.2        9.04                  0.4
# 2017-05-05 00:30:00     90.1        9.04                  0.4
# 2017-05-05 00:45:00     90.0        9.03                  0.4
# 2017-05-05 01:00:00     89.8        9.02                  0.4
#
#                                datetime
# timestamp
# 2017-05-05 00:00:00 2017-05-05 00:00:00
# 2017-05-05 00:15:00 2017-05-05 00:15:00
# 2017-05-05 00:30:00 2017-05-05 00:30:00
# 2017-05-05 00:45:00 2017-05-05 00:45:00
# 2017-05-05 01:00:00 2017-05-05 01:00:00

# %%
# Now to datetime index our 2018 data
for i in range(0, len(test_dfs)):
    timestamp = pd.to_datetime(test_dfs[i]['Time America/Boise UTC-06:00'])
    test_dfs[i]['timestamp'] = timestamp
    test_dfs[i]['datetime'] = timestamp
    test_dfs[i] = test_dfs[i].set_index('timestamp')
    test_dfs[i] = test_dfs[i].drop(columns=['Time America/Boise UTC-06:00'])
test_dfs[test_index].head()
# Out:
#                      Temp C  Sp Cond (uS/cm)  pH (mV)    pH  Turbidity (NTU)  \
# timestamp
# 2018-04-11 10:30:00   11.88             1782   -146.1  8.20            42.49
# 2018-04-11 10:45:00   11.78             1783   -143.7  8.15            42.89
# 2018-04-11 11:00:00   11.79             1784   -144.3  8.17            41.24
# 2018-04-11 11:15:00   11.66             1783   -143.1  8.14            42.65
# 2018-04-11 11:30:00   11.68             1784   -143.5  8.15            42.06
#
#                      ODOSat%  ODO (mg/L)  BGA-Phycocyanin RFU  \
# timestamp
# 2018-04-11 10:30:00     89.1        9.58                  0.6
# 2018-04-11 10:45:00     87.4        9.42                  0.6
# 2018-04-11 11:00:00     89.0        9.58                  0.7
# 2018-04-11 11:15:00     87.1        9.41                  0.7
# 2018-04-11 11:30:00     87.5        9.45                  0.7
#
#                                datetime
# timestamp
# 2018-04-11 10:30:00 2018-04-11 10:30:00
# 2018-04-11 10:45:00 2018-04-11 10:45:00
# 2018-04-11 11:00:00 2018-04-11 11:00:00
# 2018-04-11 11:15:00 2018-04-11 11:15:00
# 2018-04-11 11:30:00 2018-04-11 11:30:00

# %% [markdown]
# ## Fill missing values

# %%
# Fill all missing values with the mean
for df in test_dfs + train_dfs:
    for column in df.columns:
        number_null = np.sum(df[column].isnull())
        column_length = len(df[column])
        print('{} percent null: {:.1f}%'.format(
            column, (number_null / column_length) * 100))
        if number_null > 0:
            print("Filling {} with mean: {}\n".format(column, df[column].mean()))
            df[column] = df[column].fillna(df[column].mean())
# Out:
# Temp C percent null: 0.0%
# Sp Cond (uS/cm) percent null: 0.0%
# pH (mV) percent null: 0.0%
# pH percent null: 0.0%
# Turbidity (NTU) percent null: 0.0%
# ODOSat% percent null: 0.0%
# ODO (mg/L) percent null: 0.0%
# BGA-Phycocyanin RFU percent null: 0.0%
# datetime percent null: 0.0%
# Temp C percent null: 0.0%
# Sp Cond (uS/cm) percent null: 0.0%
# pH (mV) percent null: 0.0%
# pH percent null: 0.0%
# Turbidity (NTU) percent null: 0.0%
# ODOSat% percent null: 0.0%
# ODO (mg/L) percent null: 0.0%
# BGA-Phycocyanin RFU percent null: 0.0%
# datetime percent null: 0.0%
# Temp C percent null: 0.0%
# Sp Cond (uS/cm) percent null: 0.0%
# pH (mV) percent null: 0.0%
# pH percent null: 0.0%
# Turbidity (NTU) percent null: 0.0%
# ODOSat% percent null: 0.0%
# ODO (mg/L) percent null: 0.0%
# BGA-Phycocyanin RFU percent null: 0.0%
# datetime percent null: 0.0%
# Temp C percent null: 0.0%
# Sp Cond (uS/cm) percent null: 0.0%
# pH (mV) percent null: 0.0%
# pH percent null: 0.0%
# Turbidity (NTU) percent null: 3.2%
# Filling Turbidity (NTU) with mean: 64.96250665432234
#
# ODOSat% percent null: 0.0%
# ODO (mg/L) percent null: 0.0%
# BGA-Phycocyanin RFU percent null: 0.0%
# datetime percent null: 0.0%

# %% [markdown]
# ## Add Weather Data

# %%
## Import And Clean Weather Data
weather = pd.read_csv('../../data/cleaned/daily_weather_metric_2017_2018.csv')

# Find out how much of the data is missing for each column.
drop_columns = []
missing_threshold = .05
for column in weather.columns:
    number_null = np.sum(weather[column].isnull())
    column_length = len(weather[column])
    should_drop_column = (number_null / column_length) > missing_threshold
    print('{} percent null: {:.1f}%'.format(column, (number_null / column_length) * 100))
    if should_drop_column:
        drop_columns.append(column)
print('dropping columns: {}'.format(drop_columns))
weather = weather.drop(drop_columns, axis=1)

# Drop the columns we will not be using.
weather = weather.drop(columns=['STATION','NAME','LATITUDE','LONGITUDE','ELEVATION', 'TOBS'])

weather['DATE'] = pd.to_datetime(weather['DATE'])
# Set a datetime index for convenience
weather['timestamp'] = weather['DATE']
weather = weather.set_index('timestamp')
print(weather.dtypes)

weather['DATE'] = weather['DATE'].apply(lambda x: x.date())
# Out:
# STATION percent null: 0.0%
# NAME percent null: 0.0%
# LATITUDE percent null: 0.0%
# LONGITUDE percent null: 0.0%
# ELEVATION percent null: 0.0%
# DATE percent null: 0.0%
# DAPR percent null: 99.7%
# EVAP percent null: 50.6%
# MDPR percent null: 99.7%
# MNPN percent null: 50.9%
# MXPN percent null: 50.9%
# PRCP percent null: 0.9%
# SNOW percent null: 0.5%
# SNWD percent null: 0.5%
# TAVG percent null: 100.0%
# TMAX percent null: 0.2%
# TMIN percent null: 0.0%
# TOBS percent null: 0.5%
# WESD percent null: 100.0%
# WESF percent null: 100.0%
# WT01 percent null: 100.0%
# WT03 percent null: 99.5%
# WT04 percent null: 100.0%
# WT05 percent null: 100.0%
# WT11 percent null: 100.0%
# dropping columns: ['DAPR', 'EVAP', 'MDPR', 'MNPN', 'MXPN', 'TAVG', 'WESD', 'WESF', 'WT01', 'WT03', 'WT04', 'WT05', 'WT11']
# DATE    datetime64[ns]
# PRCP           float64
# SNOW           float64
# SNWD           float64
# TMAX           float64
# TMIN           float64
# dtype: object

# %%
# Add the weather data to our training/testing sets
count = 0
total = len(train_dfs + test_dfs)
for df in train_dfs + test_dfs:
    count += 1
    print("starting dataframe {}/{}".format(count, total))
    for column in weather.drop(columns='DATE').columns:
        print("adding series for column:", column)
        values = []
        old_datetime = None
        value = None
        for d in df['datetime']:
            d = d.date()
            if d != old_datetime:
                old_datetime = d
                value = weather[weather['DATE'] == d][column]
            values.append(value.values[0] if len(value.values) > 0 else np.nan)
        df[column] = values
# Out:
# starting dataframe 1/4
# adding series for column: PRCP
# adding series for column: SNOW
# adding series for column: SNWD
# adding series for column: TMAX
# adding series for column: TMIN
# starting dataframe 2/4
# adding series for column: PRCP
# adding series for column: SNOW
# adding series for column: SNWD
# adding series for column: TMAX
# adding series for column: TMIN
# starting dataframe 3/4
# adding series for column: PRCP
# adding series for column: SNOW
# adding series for column: SNWD
# adding series for column: TMAX
# adding series for column: TMIN
# starting dataframe 4/4
# adding series for column: PRCP
# adding series for column: SNOW
# adding series for column: SNWD
# adding series for column: TMAX
# adding series for column: TMIN

# %% [markdown]
# ### Adding the Wind to weather

# %%
weather_files = ['../../data/raw_data/weather/provo_airport_2017', '../../data/raw_data/weather/provo_airport_2018']
# the array to store the readings in
contents = []

# Extract the weather data in the ISD format
for file in weather_files:
    contents.append(hf.extract_weather_data(file))

# %%
# the dfs containing the wind information for the readings.
wind_frame_2017 = pd.DataFrame(columns=["angle","speed"])
wind_frame_2018 = pd.DataFrame(columns=["angle","speed"])


wind_frames = [wind_frame_2017, wind_frame_2018]
for i in range(len(contents)):
    wind_dict = {}
    for reading in contents[i]:
        reading.GPO_timestamp = hf.round_time(reading.GPO_timestamp)

        # no key value made yet
        if reading.GPO_timestamp not in wind_dict.keys():
            # check to see if the readings are valid
            # Sets them to 'invalid' so that when we inpute them it can be handled
            if reading.WO_wind_angle == '999':
                reading.WO_wind_angle = np.nan
            else:
                reading.WO_wind_angle = int(reading.WO_wind_angle)
            if reading.WO_wind_speed == '9999':
                reading.WO_wind_speed = np.nan
            else:
                reading.WO_wind_speed = int(reading.WO_wind_speed)
            wind_dict[reading.GPO_timestamp] = [reading.WO_wind_angle, reading.WO_wind_speed]
    wind_frames[i] = pd.DataFrame.from_dict(wind_dict, orient='index')
    wind_frames[i] = wind_frames[i].rename(columns={0:'Wind Angle', 1:'Wind Speed'})

# %%
#we need to join the wind data now to the existing dataframes, but the dont care about

for i in range(len(train_dfs)):
    # train dfs is the 2017 data set so we need to set the wind frame to that 
    # dataset
    train_dfs[i] = train_dfs[i].join(wind_frames[0])
for i in range(len(test_dfs)):
    # test dfs is the 2018 data set so we need to set the wind frame to that
    # dataset
    test_dfs[i] = test_dfs[i].join(wind_frames[1])

# %% [markdown]
# Need to deal with the NaNs in the dataframe for the WInd Angle and Wind Speed. There is a couple of ways that we can do this. One way is to assume that the wind doesn't change direction from the last valid responce (or the next in the case where the first entry is a NaN) or to assume that weather acts predictibly and will change direction and angle easily from entry to entry.
#
# I.E first entry 120 angle and 36 m/s speed, second (valid) entry 160 angle and 24 m/s speed slowing pan the angle inbetween and decrese the speed throughout so the entrries would look something like this:
#
# From:
#
# |Time Stamp|angle | speed |
# |--|--|--|
# |2018-04-11 12:00:00|120|36|
# |2018-04-11 12:15:00|NaN|NaN|
# |2018-04-11 12:30:00|NaN|NaN|
# |2018-04-11 12:45:00|NaN|NaN|
# |2018-04-11 13:00:00|160|24|
#
# To:
#
# |Time Stamp|angle | speed |
# |--|--|--|
# |2018-04-11 12:00:00|120|36|
# |2018-04-11 12:15:00|130|33 |
# |2018-04-11 12:30:00|140|30 |
# |2018-04-11 12:45:00|150|27 |
# |2018-04-11 13:00:00|160|24 |

# %%
for i in range(len(train_dfs)):
    train_dfs[i]['Wind Angle'] = train_dfs[i]['Wind Angle'].interpolate(limit_direction='both')
    train_dfs[i]['Wind Speed'] = train_dfs[i]['Wind Speed'].interpolate(limit_direction='both')
for i in range(len(test_dfs)):
    #test dfs is the 2018 data set so we need to set the wind frame to that dataset
    test_dfs[i]['Wind Angle'] = test_dfs[i]['Wind Angle'].interpolate(limit_direction='both')
    test_dfs[i]['Wind Speed'] = test_dfs[i]['Wind Speed'].interpolate(limit_direction='both')

# %% [markdown]
# ## Extract Windows

# %%
x_window = pd.Timedelta('28 days')
# Segment each data frame
for i in range(0, len(train_dfs)):
    print("Windowizing 2017 data set:", i)
    train_dfs[i] = hf.data_window_reduction(
        train_dfs[i], 'datetime', target_column, x_win_size=x_window)
    print("Windowizing 2018 data set:", i)
    test_dfs[i] = hf.data_window_reduction(
        test_dfs[i], 'datetime', target_column, x_win_size=x_window)
    print()
# Out:
# Windowizing 2017 data set: 0
# Segmenting...
# Extracting feature windows...
# Extracting target windows...
# Combining extractions...
# Windowizing 2018 data set: 0
# Segmenting...
# Extracting feature windows...
# Extracting target windows...
# Combining extractions...
#
# Windowizing 2017 data set: 1
# Segmenting...
# Extracting feature windows...
# Extracting target windows...
# Combining extractions...
# Windowizing 2018 data set: 1
# Segmenting...
# Extracting feature windows...
# Extracting target windows...
# Combining extractions...

# %% [markdown]
# ## Add Weather Categories

# %%
# Add a rainy category
for df in test_dfs + train_dfs:
    df['rained'] = df['PRCP'].apply(
        lambda x: 1 if x > 0 else 0).astype('category')
test_dfs[test_index].columns

# add the weather columns to our x_columns
x_columns = list(set(x_columns 
                     + ['PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN', 'rained', 'Wind Speed', 'Wind Angle']))

# %% [markdown]
# ## Logistic Regression Model

# %%
lrf.add_target_column(train_dfs + test_dfs, 
                      threshold=RFU_THRESHOLD)

# %% [markdown]
# ### Turbidity investigation

# %%
# We are missing some Turbidity data in the 2017 marina set which may be effecting the model's performance since it occurs 
# about 3-4 weeks prior to the first major bloom in 2017, well within the 28 day window size. 
# The missing Turbidity data has been Imputed with the mean value

max_iter = 25000
loss = "log"
columns = ['Turbidity (NTU)']

marina_accuracies = []
vineyard_accuracies = []
# Cross train turbidity only at each site
for i in range(len(train_dfs)):
    train = train_dfs[i].copy()
    for j in range(len(test_dfs)):
        test = test_dfs[j].copy()
        print("Training on:", train_files[i])
        print("Testing on:", test_files[j])
        model = SGDClassifier(max_iter=max_iter, loss=loss)
        accuracy, recall, precision, cm, _, _, _ = lrf.train_model(
            model, train, test, columns, 'bloom')
        print("Accuracy", accuracy)
        print("Recall:", recall)
        print("Precision", precision)
        print("Confusion Matrix:\n", cm)
        if i == 0:
            vineyard_accuracies.append(accuracy)
        else:
            marina_accuracies.append(accuracy)
            
        # Cross train
        print("Training on:", test_files[j])
        print("Testing on:", train_files[i])
        model = SGDClassifier(max_iter=max_iter, loss=loss)
        accuracy, recall, precision, cm, _, _, _ = lrf.train_model(
            model, test, train, columns, 'bloom')
        print("Accuracy", accuracy)
        print("Recall:", recall)
        print("Precision", precision)
        print("Confusion Matrix:\n", cm)
        if i == 0:
            vineyard_accuracies.append(accuracy)
        else:
            marina_accuracies.append(accuracy)
            
print("Vineyard Accuracies:", vineyard_accuracies)
print("Marina Accuracies:", marina_accuracies)
print("Vineyard mean accuracy:", np.mean(vineyard_accuracies))
print("Marina mean accuracy:", np.mean(marina_accuracies))
# Out:
# Training on: ../../data/cleaned/utah_2017_vineyard.csv
# Testing on: ../../data/cleaned/utah_2018_marina.csv
# Accuracy 0.45484949832775917
# Recall: 0.5775401069518716
# Precision 0.5625
# Confusion Matrix:
#  [[ 28  84]
#  [ 79 108]]
# Training on: ../../data/cleaned/utah_2018_marina.csv
# Testing on: ../../data/cleaned/utah_2017_vineyard.csv
# Accuracy 0.43252595155709345
# Recall: 0.9615384615384616
# Precision 0.44014084507042256
# Confusion Matrix:
#  [[  0 159]
#  [  5 125]]
# Training on: ../../data/cleaned/utah_2017_vineyard.csv
# Testing on: ../../data/cleaned/utah_2018_bird.csv
# Accuracy 0.49498327759197325
# Recall: 0.4263157894736842
# Precision 0.6585365853658537
# Confusion Matrix:
#  [[ 67  42]
#  [109  81]]
# Training on: ../../data/cleaned/utah_2018_bird.csv
# Testing on: ../../data/cleaned/utah_2017_vineyard.csv
# Accuracy 0.4740484429065744
# Recall: 0.9538461538461539
# Precision 0.45925925925925926
# Confusion Matrix:
#  [[ 13 146]
#  [  6 124]]
# Training on: ../../data/cleaned/utah_2017_marina.csv
# Testing on: ../../data/cleaned/utah_2018_marina.csv
# Accuracy 0.40468227424749165
# Recall: 0.25133689839572193
# Precision 0.5529411764705883
# Confusion Matrix:
#  [[ 74  38]
#  [140  47]]
# Training on: ../../data/cleaned/utah_2018_marina.csv
# Testing on: ../../data/cleaned/utah_2017_marina.csv
# Accuracy 0.5444444444444444
# Recall: 0.9310344827586207
# Precision 0.484304932735426
# Confusion Matrix:
#  [[ 39 115]
#  [  8 108]]
# Training on: ../../data/cleaned/utah_2017_marina.csv
# Testing on: ../../data/cleaned/utah_2018_bird.csv
# Accuracy 0.3779264214046823
# Recall: 0.13157894736842105
# Precision 0.5434782608695652
# Confusion Matrix:
#  [[ 88  21]
#  [165  25]]
# Training on: ../../data/cleaned/utah_2018_bird.csv
# Testing on: ../../data/cleaned/utah_2017_marina.csv
# Accuracy 0.5888888888888889
# Recall: 1.0
# Precision 0.5110132158590308
# Confusion Matrix:
#  [[ 43 111]
#  [  0 116]]
# Vineyard Accuracies: [0.45484949832775917, 0.43252595155709345, 0.49498327759197325, 0.4740484429065744]
# Marina Accuracies: [0.40468227424749165, 0.5444444444444444, 0.3779264214046823, 0.5888888888888889]
# Vineyard mean accuracy: 0.46410179259585005
# Marina mean accuracy: 0.4789855072463768

# %% [markdown]
# We see more varience but not much difference in the average.
# #### Greedy algorithm on each site

# %%
max_iter = 25000
loss = "log"

marina_accuracies = []
vineyard_accuracies = []
# Cross train turbidity only at each site
for i in range(len(train_dfs)):
    train = train_dfs[i].copy()
    for j in range(len(test_dfs)):
        test = test_dfs[j].copy()
        print("Training on:", train_files[i])
        print("Testing on:", test_files[j])
        sorted_columns = lrf.sort_columns_by_metric(model, train, 
                                            test,
                                            x_columns,
                                            'bloom', verbose=0)
        model = SGDClassifier(max_iter=max_iter, loss=loss)
        accuracy, recall, precision, cm, _, _, _ = lrf.greedy_model(
            model, train, test, x_columns, 'bloom', sorted_columns)
        print("Accuracy", accuracy)
        print("Recall:", recall)
        print("Precision", precision)
        print("Confusion Matrix:\n", cm)
        if i == 0:
            vineyard_accuracies.append(accuracy)
        else:
            marina_accuracies.append(accuracy)
            
        # Cross train
        print("Training on:", test_files[j])
        print("Testing on:", train_files[i])
        sorted_columns = lrf.sort_columns_by_metric(model, train, 
                                    test,
                                    x_columns,
                                    'bloom', verbose=0)
        model = SGDClassifier(max_iter=max_iter, loss=loss)
        accuracy, recall, precision, cm, _, _, _ = lrf.greedy_model(
            model, test, train, x_columns, 'bloom', sorted_columns)
        print("Accuracy", accuracy)
        print("Recall:", recall)
        print("Precision", precision)
        print("Confusion Matrix:\n", cm)
        if i == 0:
            vineyard_accuracies.append(accuracy)
        else:
            marina_accuracies.append(accuracy)
            
print("Vineyard Accuracies:", vineyard_accuracies)
print("Marina Accuracies:", marina_accuracies)
print("Vineyard mean accuracy:", np.mean(vineyard_accuracies))
print("Marina mean accuracy:", np.mean(marina_accuracies))
# Out:
# Training on: ../../data/cleaned/utah_2017_vineyard.csv
# Testing on: ../../data/cleaned/utah_2018_marina.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'TMIN', 'ODO (mg/L)', 'pH', 'Wind Speed', 'Temp C', 'TMAX', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'TMIN', 'ODO (mg/L)', 'pH', 'Wind Speed', 'Temp C', 'TMAX', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.7914438502673797
# Test model precision: 0.9367088607594937
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.8561872909698997
# Test model recall: 0.8235294117647058
# Test model precision: 0.9390243902439024
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'ODO (mg/L)']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.8074866310160428
# Test model precision: 0.9207317073170732
#
# Training model with: ['ODOSat%', 'TMIN', 'pH']
# Test model accuracy: 0.7993311036789298
# Test model recall: 0.9518716577540107
# Test model precision: 0.777292576419214
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed']
# Test model accuracy: 0.6688963210702341
# Test model recall: 0.5561497326203209
# Test model precision: 0.8666666666666667
#
# Training model with: ['ODOSat%', 'TMIN', 'Temp C']
# Test model accuracy: 0.842809364548495
# Test model recall: 0.8609625668449198
# Test model precision: 0.8846153846153846
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX']
# Test model accuracy: 0.8461538461538461
# Test model recall: 0.8128342245989305
# Test model precision: 0.9325153374233128
#
# Training model with: ['ODOSat%', 'TMIN', 'pH (mV)']
# Test model accuracy: 0.6254180602006689
# Test model recall: 1.0
# Test model precision: 0.6254180602006689
#
# Training model with: ['ODOSat%', 'TMIN', 'PRCP']
# Test model accuracy: 0.8394648829431438
# Test model recall: 0.8288770053475936
# Test model precision: 0.9064327485380117
#
# Training model with: ['ODOSat%', 'TMIN', 'Turbidity (NTU)']
# Test model accuracy: 0.44481605351170567
# Test model recall: 0.5347593582887701
# Test model precision: 0.5586592178770949
#
# Training model with: ['ODOSat%', 'TMIN', 'rained']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.8556149732620321
# Test model precision: 0.8602150537634409
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Angle']
# Test model accuracy: 0.7290969899665551
# Test model recall: 0.6577540106951871
# Test model precision: 0.8785714285714286
#
# Training model with: ['ODOSat%', 'TMIN', 'SNOW']
# Test model accuracy: 0.8561872909698997
# Test model recall: 0.8235294117647058
# Test model precision: 0.9390243902439024
#
# Training model with: ['ODOSat%', 'TMIN', 'SNWD']
# Test model accuracy: 0.8561872909698997
# Test model recall: 0.8235294117647058
# Test model precision: 0.9390243902439024
#
# Training model with: ['ODOSat%', 'TMIN', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.8394648829431438
# Test model recall: 0.9037433155080213
# Test model precision: 0.8492462311557789
#
# Final greedy columns: ['ODOSat%', 'TMIN']
# Final greedy accuracy 0.8561872909698997
# Final greedy recall: 0.8235294117647058
# Final greedy precision: 0.9390243902439024
# Final greedy confusion matrix:
#  [[102  10]
#  [ 33 154]]
# Accuracy 0.8561872909698997
# Recall: 0.8235294117647058
# Precision 0.9390243902439024
# Confusion Matrix:
#  [[102  10]
#  [ 33 154]]
# Training on: ../../data/cleaned/utah_2018_marina.csv
# Testing on: ../../data/cleaned/utah_2017_vineyard.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'TMIN', 'ODO (mg/L)', 'pH', 'Wind Speed', 'Temp C', 'TMAX', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'TMIN', 'ODO (mg/L)', 'pH', 'Wind Speed', 'Temp C', 'TMAX', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.6643598615916955
# Test model recall: 0.7384615384615385
# Test model precision: 0.6037735849056604
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.6643598615916955
# Test model recall: 0.7384615384615385
# Test model precision: 0.6037735849056604
#
# Training model with: ['ODOSat%', 'ODO (mg/L)']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7307692307692307
# Test model precision: 0.6012658227848101
#
# Training model with: ['ODOSat%', 'pH']
# Test model accuracy: 0.5467128027681661
# Test model recall: 0.38461538461538464
# Test model precision: 0.49504950495049505
#
# Training model with: ['ODOSat%', 'Wind Speed']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7076923076923077
# Test model precision: 0.6013071895424836
#
# Training model with: ['ODOSat%', 'Temp C']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7307692307692307
# Test model precision: 0.6012658227848101
#
# Training model with: ['ODOSat%', 'TMAX']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7461538461538462
# Test model precision: 0.5950920245398773
#
# Training model with: ['ODOSat%', 'pH (mV)']
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Test model accuracy: 0.5501730103806228
# Test model recall: 0.0
# Test model precision: 0.0
#
# Training model with: ['ODOSat%', 'PRCP']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7538461538461538
# Test model precision: 0.593939393939394
#
# Training model with: ['ODOSat%', 'Turbidity (NTU)']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'rained']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7461538461538462
# Test model precision: 0.5950920245398773
#
# Training model with: ['ODOSat%', 'Wind Angle']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'SNOW']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'SNWD']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7461538461538462
# Test model precision: 0.5950920245398773
#
# Final greedy columns: ['ODOSat%']
# Final greedy accuracy 0.6643598615916955
# Final greedy recall: 0.7384615384615385
# Final greedy precision: 0.6037735849056604
# Final greedy confusion matrix:
#  [[96 63]
#  [34 96]]
# Accuracy 0.6643598615916955
# Recall: 0.7384615384615385
# Precision 0.6037735849056604
# Confusion Matrix:
#  [[96 63]
#  [34 96]]
# Training on: ../../data/cleaned/utah_2017_vineyard.csv
# Testing on: ../../data/cleaned/utah_2018_bird.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['TMIN', 'Temp C', 'TMAX', 'pH', 'Wind Speed', 'pH (mV)', 'ODOSat%', 'PRCP', 'Turbidity (NTU)', 'ODO (mg/L)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['TMIN', 'Temp C', 'TMAX', 'pH', 'Wind Speed', 'pH (mV)', 'ODOSat%', 'PRCP', 'Turbidity (NTU)', 'ODO (mg/L)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# Training model with: ['TMIN']
# Test model accuracy: 0.8127090301003345
# Test model recall: 0.8
# Test model precision: 0.8941176470588236
#
# Updating greedy model
#
# Training model with: ['TMIN', 'Temp C']
# Test model accuracy: 0.8762541806020067
# Test model recall: 0.9473684210526315
# Test model precision: 0.8695652173913043
#
# Updating greedy model
#
# Training model with: ['TMIN', 'Temp C', 'TMAX']
# Test model accuracy: 0.8795986622073578
# Test model recall: 0.9473684210526315
# Test model precision: 0.8737864077669902
#
# Updating greedy model
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'pH']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.9736842105263158
# Test model precision: 0.8078602620087336
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'Wind Speed']
# Test model accuracy: 0.8561872909698997
# Test model recall: 0.8210526315789474
# Test model precision: 0.9454545454545454
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'pH (mV)']
# Test model accuracy: 0.6822742474916388
# Test model recall: 1.0
# Test model precision: 0.6666666666666666
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'ODOSat%']
# Test model accuracy: 0.8060200668896321
# Test model recall: 0.6947368421052632
# Test model precision: 1.0
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'PRCP']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.8631578947368421
# Test model precision: 0.8770053475935828
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'Turbidity (NTU)']
# Test model accuracy: 0.39464882943143814
# Test model recall: 0.3631578947368421
# Test model precision: 0.5348837209302325
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'ODO (mg/L)']
# Test model accuracy: 0.8160535117056856
# Test model recall: 0.7105263157894737
# Test model precision: 1.0
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'rained']
# Test model accuracy: 0.8595317725752508
# Test model recall: 0.8789473684210526
# Test model precision: 0.8978494623655914
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'Wind Angle']
# Test model accuracy: 0.7658862876254181
# Test model recall: 0.7052631578947368
# Test model precision: 0.9054054054054054
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'SNOW']
# Test model accuracy: 0.8795986622073578
# Test model recall: 0.9473684210526315
# Test model precision: 0.8737864077669902
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'SNWD']
# Test model accuracy: 0.8795986622073578
# Test model recall: 0.9473684210526315
# Test model precision: 0.8737864077669902
#
# Training model with: ['TMIN', 'Temp C', 'TMAX', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.8461538461538461
# Test model recall: 0.9894736842105263
# Test model precision: 0.8103448275862069
#
# Final greedy columns: ['TMIN', 'Temp C', 'TMAX']
# Final greedy accuracy 0.8795986622073578
# Final greedy recall: 0.9473684210526315
# Final greedy precision: 0.8737864077669902
# Final greedy confusion matrix:
#  [[ 83  26]
#  [ 10 180]]
# Accuracy 0.8795986622073578
# Recall: 0.9473684210526315
# Precision 0.8737864077669902
# Confusion Matrix:
#  [[ 83  26]
#  [ 10 180]]
# Training on: ../../data/cleaned/utah_2018_bird.csv
# Testing on: ../../data/cleaned/utah_2017_vineyard.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['TMIN', 'Temp C', 'TMAX', 'pH', 'Wind Speed', 'pH (mV)', 'ODOSat%', 'PRCP', 'Turbidity (NTU)', 'ODO (mg/L)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['TMIN', 'Temp C', 'TMAX', 'pH', 'Wind Speed', 'pH (mV)', 'ODOSat%', 'PRCP', 'Turbidity (NTU)', 'ODO (mg/L)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# Training model with: ['TMIN']
# Test model accuracy: 0.629757785467128
# Test model recall: 0.823076923076923
# Test model precision: 0.5602094240837696
#
# Updating greedy model
#
# Training model with: ['TMIN', 'Temp C']
# Test model accuracy: 0.629757785467128
# Test model recall: 0.823076923076923
# Test model precision: 0.5602094240837696
#
# Training model with: ['TMIN', 'TMAX']
# Test model accuracy: 0.6643598615916955
# Test model recall: 0.5769230769230769
# Test model precision: 0.6410256410256411
#
# Updating greedy model
#
# Training model with: ['TMIN', 'TMAX', 'pH']
# Test model accuracy: 0.6678200692041523
# Test model recall: 0.5769230769230769
# Test model precision: 0.646551724137931
#
# Updating greedy model
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed']
# Test model accuracy: 0.726643598615917
# Test model recall: 0.6923076923076923
# Test model precision: 0.6976744186046512
#
# Updating greedy model
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed', 'pH (mV)']
# Test model accuracy: 0.6955017301038062
# Test model recall: 0.6230769230769231
# Test model precision: 0.675
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed', 'ODOSat%']
# Test model accuracy: 0.6920415224913494
# Test model recall: 0.7076923076923077
# Test model precision: 0.6433566433566433
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed', 'PRCP']
# Test model accuracy: 0.71280276816609
# Test model recall: 0.7
# Test model precision: 0.674074074074074
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed', 'Turbidity (NTU)']
# Test model accuracy: 0.6782006920415224
# Test model recall: 0.676923076923077
# Test model precision: 0.6330935251798561
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed', 'ODO (mg/L)']
# Test model accuracy: 0.6955017301038062
# Test model recall: 0.7
# Test model precision: 0.65
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed', 'rained']
# Test model accuracy: 0.726643598615917
# Test model recall: 0.6923076923076923
# Test model precision: 0.6976744186046512
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed', 'Wind Angle']
# Test model accuracy: 0.6955017301038062
# Test model recall: 0.7
# Test model precision: 0.65
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed', 'SNOW']
# Test model accuracy: 0.726643598615917
# Test model recall: 0.6923076923076923
# Test model precision: 0.6976744186046512
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed', 'SNWD']
# Test model accuracy: 0.726643598615917
# Test model recall: 0.6923076923076923
# Test model precision: 0.6976744186046512
#
# Training model with: ['TMIN', 'TMAX', 'pH', 'Wind Speed', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.726643598615917
# Test model recall: 0.6923076923076923
# Test model precision: 0.6976744186046512
#
# Final greedy columns: ['TMIN', 'TMAX', 'pH', 'Wind Speed']
# Final greedy accuracy 0.726643598615917
# Final greedy recall: 0.6923076923076923
# Final greedy precision: 0.6976744186046512
# Final greedy confusion matrix:
#  [[120  39]
#  [ 40  90]]
# Accuracy 0.726643598615917
# Recall: 0.6923076923076923
# Precision 0.6976744186046512
# Confusion Matrix:
#  [[120  39]
#  [ 40  90]]
# Training on: ../../data/cleaned/utah_2017_marina.csv
# Testing on: ../../data/cleaned/utah_2018_marina.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'TMAX', 'Temp C', 'Wind Speed', 'pH', 'PRCP', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'TMAX', 'Temp C', 'Wind Speed', 'pH', 'PRCP', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.8127090301003345
# Test model recall: 0.7379679144385026
# Test model precision: 0.9517241379310345
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'ODO (mg/L)']
# Test model accuracy: 0.7190635451505016
# Test model recall: 0.6096256684491979
# Test model precision: 0.912
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.8193979933110368
# Test model recall: 0.7647058823529411
# Test model precision: 0.934640522875817
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX']
# Test model accuracy: 0.7190635451505016
# Test model recall: 0.6096256684491979
# Test model precision: 0.912
#
# Training model with: ['ODOSat%', 'TMIN', 'Temp C']
# Test model accuracy: 0.6588628762541806
# Test model recall: 0.46524064171123
# Test model precision: 0.9775280898876404
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed']
# Test model accuracy: 0.8193979933110368
# Test model recall: 0.7647058823529411
# Test model precision: 0.934640522875817
#
# Training model with: ['ODOSat%', 'TMIN', 'pH']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.893048128342246
# Test model precision: 0.835
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'PRCP']
# Test model accuracy: 0.7591973244147158
# Test model recall: 0.9411764705882353
# Test model precision: 0.7426160337552743
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'rained']
# Test model accuracy: 0.7491638795986622
# Test model recall: 0.9732620320855615
# Test model precision: 0.7222222222222222
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'Turbidity (NTU)']
# Test model accuracy: 0.7290969899665551
# Test model recall: 0.9893048128342246
# Test model precision: 0.7007575757575758
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'SNOW']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.893048128342246
# Test model precision: 0.835
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'pH (mV)']
# Test model accuracy: 0.6755852842809364
# Test model recall: 1.0
# Test model precision: 0.6584507042253521
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'SNWD']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.893048128342246
# Test model precision: 0.835
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'Wind Angle']
# Test model accuracy: 0.8260869565217391
# Test model recall: 0.8663101604278075
# Test model precision: 0.8571428571428571
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'Wind Angle', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.6086956521739131
# Test model recall: 0.8663101604278075
# Test model precision: 0.6377952755905512
#
# Final greedy columns: ['ODOSat%', 'TMIN', 'pH', 'Wind Angle']
# Final greedy accuracy 0.8260869565217391
# Final greedy recall: 0.8663101604278075
# Final greedy precision: 0.8571428571428571
# Final greedy confusion matrix:
#  [[ 85  27]
#  [ 25 162]]
# Accuracy 0.8260869565217391
# Recall: 0.8663101604278075
# Precision 0.8571428571428571
# Confusion Matrix:
#  [[ 85  27]
#  [ 25 162]]
# Training on: ../../data/cleaned/utah_2018_marina.csv
# Testing on: ../../data/cleaned/utah_2017_marina.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'TMAX', 'Temp C', 'Wind Speed', 'pH', 'PRCP', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'TMAX', 'Temp C', 'Wind Speed', 'pH', 'PRCP', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.7185185185185186
# Test model recall: 0.853448275862069
# Test model precision: 0.6265822784810127
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'ODO (mg/L)']
# Test model accuracy: 0.7185185185185186
# Test model recall: 0.853448275862069
# Test model precision: 0.6265822784810127
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.737037037037037
# Test model recall: 0.8793103448275862
# Test model precision: 0.6415094339622641
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX']
# Test model accuracy: 0.7296296296296296
# Test model recall: 0.6982758620689655
# Test model precision: 0.680672268907563
#
# Training model with: ['ODOSat%', 'TMIN', 'Temp C']
# Test model accuracy: 0.6925925925925925
# Test model recall: 0.6551724137931034
# Test model precision: 0.6386554621848739
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed']
# Test model accuracy: 0.7518518518518519
# Test model recall: 0.8189655172413793
# Test model precision: 0.6737588652482269
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH']
# Test model accuracy: 0.7666666666666667
# Test model recall: 0.7758620689655172
# Test model precision: 0.7086614173228346
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'PRCP']
# Test model accuracy: 0.7333333333333333
# Test model recall: 0.7413793103448276
# Test model precision: 0.671875
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'rained']
# Test model accuracy: 0.7666666666666667
# Test model recall: 0.7758620689655172
# Test model precision: 0.7086614173228346
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'Turbidity (NTU)']
# Test model accuracy: 0.7296296296296296
# Test model recall: 0.7758620689655172
# Test model precision: 0.656934306569343
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'SNOW']
# Test model accuracy: 0.7666666666666667
# Test model recall: 0.7758620689655172
# Test model precision: 0.7086614173228346
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'pH (mV)']
# Test model accuracy: 0.762962962962963
# Test model recall: 0.7672413793103449
# Test model precision: 0.7063492063492064
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'SNWD']
# Test model accuracy: 0.7666666666666667
# Test model recall: 0.7758620689655172
# Test model precision: 0.7086614173228346
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'Wind Angle']
# Test model accuracy: 0.7518518518518519
# Test model recall: 0.7931034482758621
# Test model precision: 0.6814814814814815
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.7666666666666667
# Test model recall: 0.7758620689655172
# Test model precision: 0.7086614173228346
#
# Final greedy columns: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH']
# Final greedy accuracy 0.7666666666666667
# Final greedy recall: 0.7758620689655172
# Final greedy precision: 0.7086614173228346
# Final greedy confusion matrix:
#  [[117  37]
#  [ 26  90]]
# Accuracy 0.7666666666666667
# Recall: 0.7758620689655172
# Precision 0.7086614173228346
# Confusion Matrix:
#  [[117  37]
#  [ 26  90]]
# Training on: ../../data/cleaned/utah_2017_marina.csv
# Testing on: ../../data/cleaned/utah_2018_bird.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['TMIN', 'TMAX', 'Temp C', 'pH', 'ODOSat%', 'Wind Speed', 'PRCP', 'ODO (mg/L)', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['TMIN', 'TMAX', 'Temp C', 'pH', 'ODOSat%', 'Wind Speed', 'PRCP', 'ODO (mg/L)', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# Training model with: ['TMIN']
# Test model accuracy: 0.8127090301003345
# Test model recall: 0.8
# Test model precision: 0.8941176470588236
#
# Updating greedy model
#
# Training model with: ['TMIN', 'TMAX']
# Test model accuracy: 0.7290969899665551
# Test model recall: 0.631578947368421
# Test model precision: 0.916030534351145
#
# Training model with: ['TMIN', 'Temp C']
# Test model accuracy: 0.6488294314381271
# Test model recall: 0.4473684210526316
# Test model precision: 1.0
#
# Training model with: ['TMIN', 'pH']
# Test model accuracy: 0.882943143812709
# Test model recall: 0.8631578947368421
# Test model precision: 0.9479768786127167
#
# Updating greedy model
#
# Training model with: ['TMIN', 'pH', 'ODOSat%']
# Test model accuracy: 0.8327759197324415
# Test model recall: 0.7736842105263158
# Test model precision: 0.9545454545454546
#
# Training model with: ['TMIN', 'pH', 'Wind Speed']
# Test model accuracy: 0.8729096989966555
# Test model recall: 0.8789473684210526
# Test model precision: 0.9175824175824175
#
# Training model with: ['TMIN', 'pH', 'PRCP']
# Test model accuracy: 0.862876254180602
# Test model recall: 0.8842105263157894
# Test model precision: 0.8983957219251337
#
# Training model with: ['TMIN', 'pH', 'ODO (mg/L)']
# Test model accuracy: 0.882943143812709
# Test model recall: 0.8578947368421053
# Test model precision: 0.9532163742690059
#
# Training model with: ['TMIN', 'pH', 'rained']
# Test model accuracy: 0.8260869565217391
# Test model recall: 0.8789473684210526
# Test model precision: 0.8520408163265306
#
# Training model with: ['TMIN', 'pH', 'Turbidity (NTU)']
# Test model accuracy: 0.7892976588628763
# Test model recall: 0.7526315789473684
# Test model precision: 0.89937106918239
#
# Training model with: ['TMIN', 'pH', 'SNOW']
# Test model accuracy: 0.882943143812709
# Test model recall: 0.8631578947368421
# Test model precision: 0.9479768786127167
#
# Training model with: ['TMIN', 'pH', 'pH (mV)']
# Test model accuracy: 0.8795986622073578
# Test model recall: 0.9473684210526315
# Test model precision: 0.8737864077669902
#
# Training model with: ['TMIN', 'pH', 'SNWD']
# Test model accuracy: 0.882943143812709
# Test model recall: 0.8631578947368421
# Test model precision: 0.9479768786127167
#
# Training model with: ['TMIN', 'pH', 'Wind Angle']
# Test model accuracy: 0.7725752508361204
# Test model recall: 0.7
# Test model precision: 0.9236111111111112
#
# Training model with: ['TMIN', 'pH', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.6220735785953178
# Test model recall: 0.4052631578947368
# Test model precision: 1.0
#
# Final greedy columns: ['TMIN', 'pH']
# Final greedy accuracy 0.882943143812709
# Final greedy recall: 0.8631578947368421
# Final greedy precision: 0.9479768786127167
# Final greedy confusion matrix:
#  [[100   9]
#  [ 26 164]]
# Accuracy 0.882943143812709
# Recall: 0.8631578947368421
# Precision 0.9479768786127167
# Confusion Matrix:
#  [[100   9]
#  [ 26 164]]
# Training on: ../../data/cleaned/utah_2018_bird.csv
# Testing on: ../../data/cleaned/utah_2017_marina.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['TMIN', 'TMAX', 'Temp C', 'pH', 'ODOSat%', 'Wind Speed', 'PRCP', 'ODO (mg/L)', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['TMIN', 'TMAX', 'Temp C', 'pH', 'ODOSat%', 'Wind Speed', 'PRCP', 'ODO (mg/L)', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# Training model with: ['TMIN']
# Test model accuracy: 0.7
# Test model recall: 0.9741379310344828
# Test model precision: 0.5916230366492147
#
# Updating greedy model
#
# Training model with: ['TMIN', 'TMAX']
# Test model accuracy: 0.6925925925925925
# Test model recall: 0.646551724137931
# Test model precision: 0.6410256410256411
#
# Training model with: ['TMIN', 'Temp C']
# Test model accuracy: 0.7
# Test model recall: 0.9741379310344828
# Test model precision: 0.5916230366492147
#
# Training model with: ['TMIN', 'pH']
# Test model accuracy: 0.7703703703703704
# Test model recall: 0.8879310344827587
# Test model precision: 0.6776315789473685
#
# Updating greedy model
#
# Training model with: ['TMIN', 'pH', 'ODOSat%']
# Test model accuracy: 0.7592592592592593
# Test model recall: 0.9482758620689655
# Test model precision: 0.650887573964497
#
# Training model with: ['TMIN', 'pH', 'Wind Speed']
# Test model accuracy: 0.7481481481481481
# Test model recall: 0.8103448275862069
# Test model precision: 0.6714285714285714
#
# Training model with: ['TMIN', 'pH', 'PRCP']
# Test model accuracy: 0.6888888888888889
# Test model recall: 0.8103448275862069
# Test model precision: 0.6025641025641025
#
# Training model with: ['TMIN', 'pH', 'ODO (mg/L)']
# Test model accuracy: 0.7851851851851852
# Test model recall: 0.9482758620689655
# Test model precision: 0.6790123456790124
#
# Updating greedy model
#
# Training model with: ['TMIN', 'pH', 'ODO (mg/L)', 'rained']
# Test model accuracy: 0.774074074074074
# Test model recall: 0.9224137931034483
# Test model precision: 0.6729559748427673
#
# Training model with: ['TMIN', 'pH', 'ODO (mg/L)', 'Turbidity (NTU)']
# Test model accuracy: 0.7703703703703704
# Test model recall: 0.9741379310344828
# Test model precision: 0.6569767441860465
#
# Training model with: ['TMIN', 'pH', 'ODO (mg/L)', 'SNOW']
# Test model accuracy: 0.7777777777777778
# Test model recall: 0.9482758620689655
# Test model precision: 0.6707317073170732
#
# Training model with: ['TMIN', 'pH', 'ODO (mg/L)', 'pH (mV)']
# Test model accuracy: 0.7037037037037037
# Test model recall: 0.7068965517241379
# Test model precision: 0.640625
#
# Training model with: ['TMIN', 'pH', 'ODO (mg/L)', 'SNWD']
# Test model accuracy: 0.7777777777777778
# Test model recall: 0.9482758620689655
# Test model precision: 0.6707317073170732
#
# Training model with: ['TMIN', 'pH', 'ODO (mg/L)', 'Wind Angle']
# Test model accuracy: 0.774074074074074
# Test model recall: 0.9224137931034483
# Test model precision: 0.6729559748427673
#
# Training model with: ['TMIN', 'pH', 'ODO (mg/L)', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.762962962962963
# Test model recall: 0.896551724137931
# Test model precision: 0.6666666666666666
#
# Final greedy columns: ['TMIN', 'pH', 'ODO (mg/L)']
# Final greedy accuracy 0.7851851851851852
# Final greedy recall: 0.9482758620689655
# Final greedy precision: 0.6790123456790124
# Final greedy confusion matrix:
#  [[102  52]
#  [  6 110]]
# Accuracy 0.7851851851851852
# Recall: 0.9482758620689655
# Precision 0.6790123456790124
# Confusion Matrix:
#  [[102  52]
#  [  6 110]]
# Vineyard Accuracies: [0.8561872909698997, 0.6643598615916955, 0.8795986622073578, 0.726643598615917]
# Marina Accuracies: [0.8260869565217391, 0.7666666666666667, 0.882943143812709, 0.7851851851851852]
# Vineyard mean accuracy: 0.7816973533462175
# Marina mean accuracy: 0.815220488046575

# %% [markdown]
# Marina did slightly better on average yet again
# #### Combining the 2018 data sets

# %%
max_iter = 25000
loss = "log"

marina_accuracies = []
vineyard_accuracies = []
# Cross train turbidity only at each site
for i in range(len(train_dfs)):
    train = train_dfs[i].copy()
    test = test_dfs[0].copy()
    test.append(test_dfs[1].copy())
    print("Training on:", train_files[i])
    print("Testing on combined 2018")
    sorted_columns = lrf.sort_columns_by_metric(model, train, 
                                        test,
                                        x_columns,
                                        'bloom', verbose=0)
    model = SGDClassifier(max_iter=max_iter, loss=loss)
    accuracy, recall, precision, cm, _, _, _ = lrf.greedy_model(
        model, train, test, x_columns, 'bloom', sorted_columns)
    print("Accuracy", accuracy)
    print("Recall:", recall)
    print("Precision", precision)
    print("Confusion Matrix:\n", cm)
    if i == 0:
        vineyard_accuracies.append(accuracy)
    else:
        marina_accuracies.append(accuracy)

    # Cross train
    print("Training on combined 2018")
    print("Testing on:", train_files[i])
    sorted_columns = lrf.sort_columns_by_metric(model, train, 
                                test,
                                x_columns,
                                'bloom', verbose=0)
    model = SGDClassifier(max_iter=max_iter, loss=loss)
    accuracy, recall, precision, cm, _, _, _ = lrf.greedy_model(
        model, test, train, x_columns, 'bloom', sorted_columns)
    print("Accuracy", accuracy)
    print("Recall:", recall)
    print("Precision", precision)
    print("Confusion Matrix:\n", cm)
    if i == 0:
        vineyard_accuracies.append(accuracy)
    else:
        marina_accuracies.append(accuracy)
        
print("Vineyard Accuracies:", vineyard_accuracies)
print("Marina Accuracies:", marina_accuracies)
print("Vineyard mean accuracy:", np.mean(vineyard_accuracies))
print("Marina mean accuracy:", np.mean(marina_accuracies))
# Out:
# Training on: ../../data/cleaned/utah_2017_vineyard.csv
# Testing on combined 2018
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'TMIN', 'ODO (mg/L)', 'pH', 'Wind Speed', 'Temp C', 'TMAX', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'TMIN', 'ODO (mg/L)', 'pH', 'Wind Speed', 'Temp C', 'TMAX', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.7914438502673797
# Test model precision: 0.9367088607594937
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.8561872909698997
# Test model recall: 0.8235294117647058
# Test model precision: 0.9390243902439024
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'ODO (mg/L)']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.8074866310160428
# Test model precision: 0.9207317073170732
#
# Training model with: ['ODOSat%', 'TMIN', 'pH']
# Test model accuracy: 0.7993311036789298
# Test model recall: 0.9518716577540107
# Test model precision: 0.777292576419214
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed']
# Test model accuracy: 0.6622073578595318
# Test model recall: 0.5454545454545454
# Test model precision: 0.864406779661017
#
# Training model with: ['ODOSat%', 'TMIN', 'Temp C']
# Test model accuracy: 0.842809364548495
# Test model recall: 0.8609625668449198
# Test model precision: 0.8846153846153846
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX']
# Test model accuracy: 0.8461538461538461
# Test model recall: 0.8128342245989305
# Test model precision: 0.9325153374233128
#
# Training model with: ['ODOSat%', 'TMIN', 'pH (mV)']
# Test model accuracy: 0.6254180602006689
# Test model recall: 1.0
# Test model precision: 0.6254180602006689
#
# Training model with: ['ODOSat%', 'TMIN', 'PRCP']
# Test model accuracy: 0.8394648829431438
# Test model recall: 0.8288770053475936
# Test model precision: 0.9064327485380117
#
# Training model with: ['ODOSat%', 'TMIN', 'Turbidity (NTU)']
# Test model accuracy: 0.44481605351170567
# Test model recall: 0.5347593582887701
# Test model precision: 0.5586592178770949
#
# Training model with: ['ODOSat%', 'TMIN', 'rained']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.8556149732620321
# Test model precision: 0.8602150537634409
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Angle']
# Test model accuracy: 0.7290969899665551
# Test model recall: 0.6577540106951871
# Test model precision: 0.8785714285714286
#
# Training model with: ['ODOSat%', 'TMIN', 'SNOW']
# Test model accuracy: 0.8561872909698997
# Test model recall: 0.8235294117647058
# Test model precision: 0.9390243902439024
#
# Training model with: ['ODOSat%', 'TMIN', 'SNWD']
# Test model accuracy: 0.8561872909698997
# Test model recall: 0.8235294117647058
# Test model precision: 0.9390243902439024
#
# Training model with: ['ODOSat%', 'TMIN', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.8394648829431438
# Test model recall: 0.9037433155080213
# Test model precision: 0.8492462311557789
#
# Final greedy columns: ['ODOSat%', 'TMIN']
# Final greedy accuracy 0.8561872909698997
# Final greedy recall: 0.8235294117647058
# Final greedy precision: 0.9390243902439024
# Final greedy confusion matrix:
#  [[102  10]
#  [ 33 154]]
# Accuracy 0.8561872909698997
# Recall: 0.8235294117647058
# Precision 0.9390243902439024
# Confusion Matrix:
#  [[102  10]
#  [ 33 154]]
# Training on combined 2018
# Testing on: ../../data/cleaned/utah_2017_vineyard.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'TMIN', 'ODO (mg/L)', 'pH', 'Wind Speed', 'Temp C', 'TMAX', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'TMIN', 'ODO (mg/L)', 'pH', 'Wind Speed', 'Temp C', 'TMAX', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.6643598615916955
# Test model recall: 0.7384615384615385
# Test model precision: 0.6037735849056604
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.6643598615916955
# Test model recall: 0.7384615384615385
# Test model precision: 0.6037735849056604
#
# Training model with: ['ODOSat%', 'ODO (mg/L)']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7307692307692307
# Test model precision: 0.6012658227848101
#
# Training model with: ['ODOSat%', 'pH']
# Test model accuracy: 0.5467128027681661
# Test model recall: 0.38461538461538464
# Test model precision: 0.49504950495049505
#
# Training model with: ['ODOSat%', 'Wind Speed']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7076923076923077
# Test model precision: 0.6013071895424836
#
# Training model with: ['ODOSat%', 'Temp C']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7307692307692307
# Test model precision: 0.6012658227848101
#
# Training model with: ['ODOSat%', 'TMAX']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7461538461538462
# Test model precision: 0.5950920245398773
#
# Training model with: ['ODOSat%', 'pH (mV)']
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Test model accuracy: 0.5501730103806228
# Test model recall: 0.0
# Test model precision: 0.0
#
# Training model with: ['ODOSat%', 'PRCP']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7538461538461538
# Test model precision: 0.593939393939394
#
# Training model with: ['ODOSat%', 'Turbidity (NTU)']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'rained']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7461538461538462
# Test model precision: 0.5950920245398773
#
# Training model with: ['ODOSat%', 'Wind Angle']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'SNOW']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'SNWD']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7461538461538462
# Test model precision: 0.5950920245398773
#
# Final greedy columns: ['ODOSat%']
# Final greedy accuracy 0.6643598615916955
# Final greedy recall: 0.7384615384615385
# Final greedy precision: 0.6037735849056604
# Final greedy confusion matrix:
#  [[96 63]
#  [34 96]]
# Accuracy 0.6643598615916955
# Recall: 0.7384615384615385
# Precision 0.6037735849056604
# Confusion Matrix:
#  [[96 63]
#  [34 96]]
# Training on: ../../data/cleaned/utah_2017_marina.csv
# Testing on combined 2018
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'TMAX', 'Temp C', 'Wind Speed', 'pH', 'PRCP', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'TMAX', 'Temp C', 'Wind Speed', 'pH', 'PRCP', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.8127090301003345
# Test model recall: 0.7379679144385026
# Test model precision: 0.9517241379310345
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'ODO (mg/L)']
# Test model accuracy: 0.7190635451505016
# Test model recall: 0.6096256684491979
# Test model precision: 0.912
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.8193979933110368
# Test model recall: 0.7647058823529411
# Test model precision: 0.934640522875817
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX']
# Test model accuracy: 0.7190635451505016
# Test model recall: 0.6096256684491979
# Test model precision: 0.912
#
# Training model with: ['ODOSat%', 'TMIN', 'Temp C']
# Test model accuracy: 0.6588628762541806
# Test model recall: 0.46524064171123
# Test model precision: 0.9775280898876404
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed']
# Test model accuracy: 0.8193979933110368
# Test model recall: 0.7647058823529411
# Test model precision: 0.934640522875817
#
# Training model with: ['ODOSat%', 'TMIN', 'pH']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.893048128342246
# Test model precision: 0.835
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'PRCP']
# Test model accuracy: 0.7591973244147158
# Test model recall: 0.9411764705882353
# Test model precision: 0.7426160337552743
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'rained']
# Test model accuracy: 0.7491638795986622
# Test model recall: 0.9732620320855615
# Test model precision: 0.7222222222222222
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'Turbidity (NTU)']
# Test model accuracy: 0.7290969899665551
# Test model recall: 0.9893048128342246
# Test model precision: 0.7007575757575758
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'SNOW']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.893048128342246
# Test model precision: 0.835
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'pH (mV)']
# Test model accuracy: 0.6755852842809364
# Test model recall: 1.0
# Test model precision: 0.6584507042253521
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'SNWD']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.893048128342246
# Test model precision: 0.835
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'Wind Angle']
# Test model accuracy: 0.8260869565217391
# Test model recall: 0.8663101604278075
# Test model precision: 0.8571428571428571
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'pH', 'Wind Angle', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.6086956521739131
# Test model recall: 0.8663101604278075
# Test model precision: 0.6377952755905512
#
# Final greedy columns: ['ODOSat%', 'TMIN', 'pH', 'Wind Angle']
# Final greedy accuracy 0.8260869565217391
# Final greedy recall: 0.8663101604278075
# Final greedy precision: 0.8571428571428571
# Final greedy confusion matrix:
#  [[ 85  27]
#  [ 25 162]]
# Accuracy 0.8260869565217391
# Recall: 0.8663101604278075
# Precision 0.8571428571428571
# Confusion Matrix:
#  [[ 85  27]
#  [ 25 162]]
# Training on combined 2018
# Testing on: ../../data/cleaned/utah_2017_marina.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'TMAX', 'Temp C', 'Wind Speed', 'pH', 'PRCP', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'TMAX', 'Temp C', 'Wind Speed', 'pH', 'PRCP', 'rained', 'Turbidity (NTU)', 'SNOW', 'pH (mV)', 'SNWD', 'Wind Angle', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.7185185185185186
# Test model recall: 0.853448275862069
# Test model precision: 0.6265822784810127
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'ODO (mg/L)']
# Test model accuracy: 0.7185185185185186
# Test model recall: 0.853448275862069
# Test model precision: 0.6265822784810127
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.737037037037037
# Test model recall: 0.8793103448275862
# Test model precision: 0.6415094339622641
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX']
# Test model accuracy: 0.7296296296296296
# Test model recall: 0.6982758620689655
# Test model precision: 0.680672268907563
#
# Training model with: ['ODOSat%', 'TMIN', 'Temp C']
# Test model accuracy: 0.6925925925925925
# Test model recall: 0.6551724137931034
# Test model precision: 0.6386554621848739
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed']
# Test model accuracy: 0.7518518518518519
# Test model recall: 0.8189655172413793
# Test model precision: 0.6737588652482269
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH']
# Test model accuracy: 0.7666666666666667
# Test model recall: 0.7758620689655172
# Test model precision: 0.7086614173228346
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'PRCP']
# Test model accuracy: 0.7333333333333333
# Test model recall: 0.7413793103448276
# Test model precision: 0.671875
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'rained']
# Test model accuracy: 0.7666666666666667
# Test model recall: 0.7758620689655172
# Test model precision: 0.7086614173228346
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'Turbidity (NTU)']
# Test model accuracy: 0.7296296296296296
# Test model recall: 0.7758620689655172
# Test model precision: 0.656934306569343
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'SNOW']
# Test model accuracy: 0.7666666666666667
# Test model recall: 0.7758620689655172
# Test model precision: 0.7086614173228346
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'pH (mV)']
# Test model accuracy: 0.762962962962963
# Test model recall: 0.7672413793103449
# Test model precision: 0.7063492063492064
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'SNWD']
# Test model accuracy: 0.7666666666666667
# Test model recall: 0.7758620689655172
# Test model precision: 0.7086614173228346
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'Wind Angle']
# Test model accuracy: 0.7518518518518519
# Test model recall: 0.7931034482758621
# Test model precision: 0.6814814814814815
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.7666666666666667
# Test model recall: 0.7758620689655172
# Test model precision: 0.7086614173228346
#
# Final greedy columns: ['ODOSat%', 'TMIN', 'Wind Speed', 'pH']
# Final greedy accuracy 0.7666666666666667
# Final greedy recall: 0.7758620689655172
# Final greedy precision: 0.7086614173228346
# Final greedy confusion matrix:
#  [[117  37]
#  [ 26  90]]
# Accuracy 0.7666666666666667
# Recall: 0.7758620689655172
# Precision 0.7086614173228346
# Confusion Matrix:
#  [[117  37]
#  [ 26  90]]
# Vineyard Accuracies: [0.8561872909698997, 0.6643598615916955]
# Marina Accuracies: [0.8260869565217391, 0.7666666666666667]
# Vineyard mean accuracy: 0.7602735762807975
# Marina mean accuracy: 0.7963768115942029

# %% [markdown]
# Marina performed better on average
# #### Combining the 2017 data sets

# %%
max_iter = 25000
loss = "log"

marina_accuracies = []
bird_accuracies = []
# Cross train turbidity only at each site
for i in range(len(test_dfs)):
    train = test_dfs[i].copy()
    test = train_dfs[0].copy()
    test.append(train_dfs[1].copy())
    print("Training on:", test_files[i])
    print("Testing on combined 2017")
    sorted_columns = lrf.sort_columns_by_metric(model, train, 
                                        test,
                                        x_columns,
                                        'bloom', verbose=0)
    model = SGDClassifier(max_iter=max_iter, loss=loss)
    accuracy, recall, precision, cm, _, _, _ = lrf.greedy_model(
        model, train, test, x_columns, 'bloom', sorted_columns)
    print("Accuracy", accuracy)
    print("Recall:", recall)
    print("Precision", precision)
    print("Confusion Matrix:\n", cm)
    if i == 1:
        bird_accuracies.append(accuracy)
    else:
        marina_accuracies.append(accuracy)

    # Cross train
    print("Training on combined 2017")
    print("Testing on:", test_files[i])
    sorted_columns = lrf.sort_columns_by_metric(model, train, 
                                test,
                                x_columns,
                                'bloom', verbose=0)
    model = SGDClassifier(max_iter=max_iter, loss=loss)
    accuracy, recall, precision, cm, _, _, _ = lrf.greedy_model(
        model, test, train, x_columns, 'bloom', sorted_columns)
    print("Accuracy", accuracy)
    print("Recall:", recall)
    print("Precision", precision)
    print("Confusion Matrix:\n", cm)
    if i == 1:
        bird_accuracies.append(accuracy)
    else:
        marina_accuracies.append(accuracy)
        
print("Bird Accuracies:", bird_accuracies)
print("Marina Accuracies:", marina_accuracies)
print("bird mean accuracy:", np.mean(bird_accuracies))
print("Marina mean accuracy:", np.mean(marina_accuracies))
# Out:
# Training on: ../../data/cleaned/utah_2018_marina.csv
# Testing on combined 2017
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'Wind Speed', 'TMIN', 'TMAX', 'Temp C', 'ODO (mg/L)', 'pH', 'pH (mV)', 'PRCP', 'Wind Angle', 'rained', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)', 'Turbidity (NTU)']
# adjusted sorted_columns: ['ODOSat%', 'Wind Speed', 'TMIN', 'TMAX', 'Temp C', 'ODO (mg/L)', 'pH', 'pH (mV)', 'PRCP', 'Wind Angle', 'rained', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)', 'Turbidity (NTU)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.6643598615916955
# Test model recall: 0.7384615384615385
# Test model precision: 0.6037735849056604
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Wind Speed']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7076923076923077
# Test model precision: 0.6013071895424836
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.6643598615916955
# Test model recall: 0.7384615384615385
# Test model precision: 0.6037735849056604
#
# Training model with: ['ODOSat%', 'TMAX']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7461538461538462
# Test model precision: 0.5950920245398773
#
# Training model with: ['ODOSat%', 'Temp C']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7307692307692307
# Test model precision: 0.6012658227848101
#
# Training model with: ['ODOSat%', 'ODO (mg/L)']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7307692307692307
# Test model precision: 0.6012658227848101
#
# Training model with: ['ODOSat%', 'pH']
# Test model accuracy: 0.5467128027681661
# Test model recall: 0.38461538461538464
# Test model precision: 0.49504950495049505
#
# Training model with: ['ODOSat%', 'pH (mV)']
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Test model accuracy: 0.5501730103806228
# Test model recall: 0.0
# Test model precision: 0.0
#
# Training model with: ['ODOSat%', 'PRCP']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7538461538461538
# Test model precision: 0.593939393939394
#
# Training model with: ['ODOSat%', 'Wind Angle']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'rained']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7461538461538462
# Test model precision: 0.5950920245398773
#
# Training model with: ['ODOSat%', 'SNOW']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'SNWD']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Training model with: ['ODOSat%', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.657439446366782
# Test model recall: 0.7461538461538462
# Test model precision: 0.5950920245398773
#
# Training model with: ['ODOSat%', 'Turbidity (NTU)']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7538461538461538
# Test model precision: 0.5975609756097561
#
# Final greedy columns: ['ODOSat%']
# Final greedy accuracy 0.6643598615916955
# Final greedy recall: 0.7384615384615385
# Final greedy precision: 0.6037735849056604
# Final greedy confusion matrix:
#  [[96 63]
#  [34 96]]
# Accuracy 0.6643598615916955
# Recall: 0.7384615384615385
# Precision 0.6037735849056604
# Confusion Matrix:
#  [[96 63]
#  [34 96]]
# Training on combined 2017
# Testing on: ../../data/cleaned/utah_2018_marina.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'Wind Speed', 'TMIN', 'TMAX', 'Temp C', 'ODO (mg/L)', 'pH', 'pH (mV)', 'PRCP', 'Wind Angle', 'rained', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)', 'Turbidity (NTU)']
# adjusted sorted_columns: ['ODOSat%', 'Wind Speed', 'TMIN', 'TMAX', 'Temp C', 'ODO (mg/L)', 'pH', 'pH (mV)', 'PRCP', 'Wind Angle', 'rained', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)', 'Turbidity (NTU)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.7914438502673797
# Test model precision: 0.9367088607594937
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Wind Speed']
# Test model accuracy: 0.7759197324414716
# Test model recall: 0.7165775401069518
# Test model precision: 0.9054054054054054
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.8561872909698997
# Test model recall: 0.8235294117647058
# Test model precision: 0.9390243902439024
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX']
# Test model accuracy: 0.8461538461538461
# Test model recall: 0.8128342245989305
# Test model precision: 0.9325153374233128
#
# Training model with: ['ODOSat%', 'TMIN', 'Temp C']
# Test model accuracy: 0.842809364548495
# Test model recall: 0.8609625668449198
# Test model precision: 0.8846153846153846
#
# Training model with: ['ODOSat%', 'TMIN', 'ODO (mg/L)']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.8074866310160428
# Test model precision: 0.9207317073170732
#
# Training model with: ['ODOSat%', 'TMIN', 'pH']
# Test model accuracy: 0.7993311036789298
# Test model recall: 0.9518716577540107
# Test model precision: 0.777292576419214
#
# Training model with: ['ODOSat%', 'TMIN', 'pH (mV)']
# Test model accuracy: 0.6254180602006689
# Test model recall: 1.0
# Test model precision: 0.6254180602006689
#
# Training model with: ['ODOSat%', 'TMIN', 'PRCP']
# Test model accuracy: 0.8394648829431438
# Test model recall: 0.8288770053475936
# Test model precision: 0.9064327485380117
#
# Training model with: ['ODOSat%', 'TMIN', 'Wind Angle']
# Test model accuracy: 0.7290969899665551
# Test model recall: 0.6577540106951871
# Test model precision: 0.8785714285714286
#
# Training model with: ['ODOSat%', 'TMIN', 'rained']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.8556149732620321
# Test model precision: 0.8602150537634409
#
# Training model with: ['ODOSat%', 'TMIN', 'SNOW']
# Test model accuracy: 0.8561872909698997
# Test model recall: 0.8235294117647058
# Test model precision: 0.9390243902439024
#
# Training model with: ['ODOSat%', 'TMIN', 'SNWD']
# Test model accuracy: 0.8561872909698997
# Test model recall: 0.8235294117647058
# Test model precision: 0.9390243902439024
#
# Training model with: ['ODOSat%', 'TMIN', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.8394648829431438
# Test model recall: 0.9037433155080213
# Test model precision: 0.8492462311557789
#
# Training model with: ['ODOSat%', 'TMIN', 'Turbidity (NTU)']
# Test model accuracy: 0.44481605351170567
# Test model recall: 0.5347593582887701
# Test model precision: 0.5586592178770949
#
# Final greedy columns: ['ODOSat%', 'TMIN']
# Final greedy accuracy 0.8561872909698997
# Final greedy recall: 0.8235294117647058
# Final greedy precision: 0.9390243902439024
# Final greedy confusion matrix:
#  [[102  10]
#  [ 33 154]]
# Accuracy 0.8561872909698997
# Recall: 0.8235294117647058
# Precision 0.9390243902439024
# Confusion Matrix:
#  [[102  10]
#  [ 33 154]]
# Training on: ../../data/cleaned/utah_2018_bird.csv
# Testing on combined 2017
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'Wind Speed', 'TMIN', 'TMAX', 'pH', 'Temp C', 'pH (mV)', 'PRCP', 'ODO (mg/L)', 'Turbidity (NTU)', 'Wind Angle', 'rained', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'Wind Speed', 'TMIN', 'TMAX', 'pH', 'Temp C', 'pH (mV)', 'PRCP', 'ODO (mg/L)', 'Turbidity (NTU)', 'Wind Angle', 'rained', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.6782006920415224
# Test model recall: 0.8076923076923077
# Test model precision: 0.6069364161849711
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Wind Speed']
# Test model accuracy: 0.6678200692041523
# Test model recall: 0.7769230769230769
# Test model precision: 0.6011904761904762
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.6228373702422145
# Test model recall: 0.8076923076923077
# Test model precision: 0.5555555555555556
#
# Training model with: ['ODOSat%', 'TMAX']
# Test model accuracy: 0.671280276816609
# Test model recall: 0.8307692307692308
# Test model precision: 0.5966850828729282
#
# Training model with: ['ODOSat%', 'pH']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7769230769230769
# Test model precision: 0.5941176470588235
#
# Training model with: ['ODOSat%', 'Temp C']
# Test model accuracy: 0.5640138408304498
# Test model recall: 0.8461538461538461
# Test model precision: 0.5092592592592593
#
# Training model with: ['ODOSat%', 'pH (mV)']
# Test model accuracy: 0.5536332179930796
# Test model recall: 0.24615384615384617
# Test model precision: 0.5079365079365079
#
# Training model with: ['ODOSat%', 'PRCP']
# Test model accuracy: 0.6747404844290658
# Test model recall: 0.8076923076923077
# Test model precision: 0.603448275862069
#
# Training model with: ['ODOSat%', 'ODO (mg/L)']
# Test model accuracy: 0.6747404844290658
# Test model recall: 0.8307692307692308
# Test model precision: 0.6
#
# Training model with: ['ODOSat%', 'Turbidity (NTU)']
# Test model accuracy: 0.6816608996539792
# Test model recall: 0.8076923076923077
# Test model precision: 0.6104651162790697
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Turbidity (NTU)', 'Wind Angle']
# Test model accuracy: 0.6816608996539792
# Test model recall: 0.8076923076923077
# Test model precision: 0.6104651162790697
#
# Training model with: ['ODOSat%', 'Turbidity (NTU)', 'rained']
# Test model accuracy: 0.6782006920415224
# Test model recall: 0.8307692307692308
# Test model precision: 0.6033519553072626
#
# Training model with: ['ODOSat%', 'Turbidity (NTU)', 'SNOW']
# Test model accuracy: 0.6782006920415224
# Test model recall: 0.8153846153846154
# Test model precision: 0.6057142857142858
#
# Training model with: ['ODOSat%', 'Turbidity (NTU)', 'SNWD']
# Test model accuracy: 0.6782006920415224
# Test model recall: 0.8153846153846154
# Test model precision: 0.6057142857142858
#
# Training model with: ['ODOSat%', 'Turbidity (NTU)', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.6608996539792388
# Test model recall: 0.7692307692307693
# Test model precision: 0.5952380952380952
#
# Final greedy columns: ['ODOSat%', 'Turbidity (NTU)']
# Final greedy accuracy 0.6816608996539792
# Final greedy recall: 0.8076923076923077
# Final greedy precision: 0.6104651162790697
# Final greedy confusion matrix:
#  [[ 92  67]
#  [ 25 105]]
# Accuracy 0.6816608996539792
# Recall: 0.8076923076923077
# Precision 0.6104651162790697
# Confusion Matrix:
#  [[ 92  67]
#  [ 25 105]]
# Training on combined 2017
# Testing on: ../../data/cleaned/utah_2018_bird.csv
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'Wind Speed', 'TMIN', 'TMAX', 'pH', 'Temp C', 'pH (mV)', 'PRCP', 'ODO (mg/L)', 'Turbidity (NTU)', 'Wind Angle', 'rained', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'Wind Speed', 'TMIN', 'TMAX', 'pH', 'Temp C', 'pH (mV)', 'PRCP', 'ODO (mg/L)', 'Turbidity (NTU)', 'Wind Angle', 'rained', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.6287625418060201
# Test model recall: 0.41578947368421054
# Test model precision: 1.0
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Wind Speed']
# Test model accuracy: 0.68561872909699
# Test model recall: 0.5105263157894737
# Test model precision: 0.9897959183673469
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN']
# Test model accuracy: 0.8193979933110368
# Test model recall: 0.8157894736842105
# Test model precision: 0.8908045977011494
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'TMAX']
# Test model accuracy: 0.8160535117056856
# Test model recall: 0.8052631578947368
# Test model precision: 0.8947368421052632
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH']
# Test model accuracy: 0.8394648829431438
# Test model recall: 0.9210526315789473
# Test model precision: 0.8413461538461539
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'Temp C']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.9473684210526315
# Test model precision: 0.821917808219178
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'pH (mV)']
# Test model accuracy: 0.6354515050167224
# Test model recall: 1.0
# Test model precision: 0.6354515050167224
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'PRCP']
# Test model accuracy: 0.8494983277591973
# Test model recall: 0.9
# Test model precision: 0.868020304568528
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'PRCP', 'ODO (mg/L)']
# Test model accuracy: 0.8494983277591973
# Test model recall: 0.9
# Test model precision: 0.868020304568528
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'PRCP', 'Turbidity (NTU)']
# Test model accuracy: 0.6086956521739131
# Test model recall: 0.6052631578947368
# Test model precision: 0.732484076433121
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'PRCP', 'Wind Angle']
# Test model accuracy: 0.7525083612040134
# Test model recall: 0.6736842105263158
# Test model precision: 0.9142857142857143
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'PRCP', 'rained']
# Test model accuracy: 0.8762541806020067
# Test model recall: 0.9210526315789473
# Test model precision: 0.8883248730964467
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'PRCP', 'rained', 'SNOW']
# Test model accuracy: 0.8762541806020067
# Test model recall: 0.9210526315789473
# Test model precision: 0.8883248730964467
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'PRCP', 'rained', 'SNWD']
# Test model accuracy: 0.8762541806020067
# Test model recall: 0.9210526315789473
# Test model precision: 0.8883248730964467
#
# Training model with: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'PRCP', 'rained', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.8595317725752508
# Test model recall: 0.9631578947368421
# Test model precision: 0.8394495412844036
#
# Final greedy columns: ['ODOSat%', 'Wind Speed', 'TMIN', 'pH', 'PRCP', 'rained']
# Final greedy accuracy 0.8762541806020067
# Final greedy recall: 0.9210526315789473
# Final greedy precision: 0.8883248730964467
# Final greedy confusion matrix:
#  [[ 87  22]
#  [ 15 175]]
# Accuracy 0.8762541806020067
# Recall: 0.9210526315789473
# Precision 0.8883248730964467
# Confusion Matrix:
#  [[ 87  22]
#  [ 15 175]]
# Bird Accuracies: [0.6816608996539792, 0.8762541806020067]
# Marina Accuracies: [0.6643598615916955, 0.8561872909698997]
# bird mean accuracy: 0.7789575401279929
# Marina mean accuracy: 0.7602735762807975

# %% [markdown]
# Training on the combined 2017 is better than testing on combined 2017
# #### Combining both datasets

# %%
max_iter = 25000
loss = "log"


# Cross train turbidity only at each site
train = train_dfs[0].copy().append(train_dfs[1])
test = test_dfs[0].copy()
test.append(test_dfs[1].copy())
print("Training on combined 2017")
print("Testing on combined 2018")
sorted_columns = lrf.sort_columns_by_metric(model, train, 
                                    test,
                                    x_columns,
                                    'bloom', verbose=0)
model = SGDClassifier(max_iter=max_iter, loss=loss)
accuracy, recall, precision, cm, _, _, _ = lrf.greedy_model(
    model, train, test, x_columns, 'bloom', sorted_columns)
print("Accuracy", accuracy)
print("Recall:", recall)
print("Precision", precision)
print("Confusion Matrix:\n", cm)

mean_accuracy = accuracy

# Cross train
print("Training on combined 2018")
print("Testing on combined 2017")
sorted_columns = lrf.sort_columns_by_metric(model, train, 
                            test,
                            x_columns,
                            'bloom', verbose=0)
model = SGDClassifier(max_iter=max_iter, loss=loss)
accuracy, recall, precision, cm, _, _, _ = lrf.greedy_model(
    model, test, train, x_columns, 'bloom', sorted_columns)
print("Accuracy", accuracy)
print("Recall:", recall)
print("Precision", precision)
print("Confusion Matrix:\n", cm)

mean_accuracy = (mean_accuracy + accuracy) / 2

print("Mean accuracy:", mean_accuracy)
# Out:
# Training on combined 2017
# Testing on combined 2018
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'pH', 'Temp C', 'TMAX', 'Wind Speed', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'pH', 'Temp C', 'TMAX', 'Wind Speed', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.8327759197324415
# Test model recall: 0.7754010695187166
# Test model precision: 0.9477124183006536
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'ODO (mg/L)']
# Test model accuracy: 0.8294314381270903
# Test model recall: 0.7807486631016043
# Test model precision: 0.9358974358974359
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.8327759197324415
# Test model recall: 0.786096256684492
# Test model precision: 0.9363057324840764
#
# Training model with: ['ODOSat%', 'pH']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.7540106951871658
# Test model precision: 0.9527027027027027
#
# Training model with: ['ODOSat%', 'Temp C']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.786096256684492
# Test model precision: 0.9423076923076923
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Temp C', 'TMAX']
# Test model accuracy: 0.8494983277591973
# Test model recall: 0.8181818181818182
# Test model precision: 0.9329268292682927
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'Temp C', 'TMAX', 'Wind Speed']
# Test model accuracy: 0.822742474916388
# Test model recall: 0.7914438502673797
# Test model precision: 0.9135802469135802
#
# Training model with: ['ODOSat%', 'Temp C', 'TMAX', 'pH (mV)']
# Test model accuracy: 0.7424749163879598
# Test model recall: 0.9625668449197861
# Test model precision: 0.72
#
# Training model with: ['ODOSat%', 'Temp C', 'TMAX', 'PRCP']
# Test model accuracy: 0.8394648829431438
# Test model recall: 0.8021390374331551
# Test model precision: 0.9316770186335404
#
# Training model with: ['ODOSat%', 'Temp C', 'TMAX', 'Turbidity (NTU)']
# Test model accuracy: 0.7324414715719063
# Test model recall: 0.6149732620320856
# Test model precision: 0.9349593495934959
#
# Training model with: ['ODOSat%', 'Temp C', 'TMAX', 'rained']
# Test model accuracy: 0.7859531772575251
# Test model recall: 0.7593582887700535
# Test model precision: 0.8819875776397516
#
# Training model with: ['ODOSat%', 'Temp C', 'TMAX', 'Wind Angle']
# Test model accuracy: 0.7290969899665551
# Test model recall: 0.6310160427807486
# Test model precision: 0.9076923076923077
#
# Training model with: ['ODOSat%', 'Temp C', 'TMAX', 'SNOW']
# Test model accuracy: 0.8494983277591973
# Test model recall: 0.8181818181818182
# Test model precision: 0.9329268292682927
#
# Training model with: ['ODOSat%', 'Temp C', 'TMAX', 'SNWD']
# Test model accuracy: 0.8494983277591973
# Test model recall: 0.8181818181818182
# Test model precision: 0.9329268292682927
#
# Training model with: ['ODOSat%', 'Temp C', 'TMAX', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.8361204013377926
# Test model recall: 0.7967914438502673
# Test model precision: 0.93125
#
# Final greedy columns: ['ODOSat%', 'Temp C', 'TMAX']
# Final greedy accuracy 0.8494983277591973
# Final greedy recall: 0.8181818181818182
# Final greedy precision: 0.9329268292682927
# Final greedy confusion matrix:
#  [[101  11]
#  [ 34 153]]
# Accuracy 0.8494983277591973
# Recall: 0.8181818181818182
# Precision 0.9329268292682927
# Confusion Matrix:
#  [[101  11]
#  [ 34 153]]
# Training on combined 2018
# Testing on combined 2017
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\mccomackjp\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# base_columns: []
# sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'pH', 'Temp C', 'TMAX', 'Wind Speed', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# adjusted sorted_columns: ['ODOSat%', 'ODO (mg/L)', 'TMIN', 'pH', 'Temp C', 'TMAX', 'Wind Speed', 'pH (mV)', 'PRCP', 'Turbidity (NTU)', 'rained', 'Wind Angle', 'SNOW', 'SNWD', 'Sp Cond (uS/cm)']
# Training model with: ['ODOSat%']
# Test model accuracy: 0.6905187835420393
# Test model recall: 0.7926829268292683
# Test model precision: 0.6151419558359621
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'ODO (mg/L)']
# Test model accuracy: 0.6887298747763864
# Test model recall: 0.7886178861788617
# Test model precision: 0.6139240506329114
#
# Training model with: ['ODOSat%', 'TMIN']
# Test model accuracy: 0.6994633273703041
# Test model recall: 0.8048780487804879
# Test model precision: 0.6226415094339622
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'pH']
# Test model accuracy: 0.6422182468694096
# Test model recall: 0.5365853658536586
# Test model precision: 0.6055045871559633
#
# Training model with: ['ODOSat%', 'TMIN', 'Temp C']
# Test model accuracy: 0.6601073345259392
# Test model recall: 0.6300813008130082
# Test model precision: 0.610236220472441
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX']
# Test model accuracy: 0.7030411449016101
# Test model recall: 0.6463414634146342
# Test model precision: 0.6680672268907563
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX', 'Wind Speed']
# Test model accuracy: 0.740608228980322
# Test model recall: 0.7398373983739838
# Test model precision: 0.6920152091254753
#
# Updating greedy model
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX', 'Wind Speed', 'pH (mV)']
# Test model accuracy: 0.7101967799642218
# Test model recall: 0.7560975609756098
# Test model precision: 0.6458333333333334
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX', 'Wind Speed', 'PRCP']
# Test model accuracy: 0.740608228980322
# Test model recall: 0.7398373983739838
# Test model precision: 0.6920152091254753
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX', 'Wind Speed', 'Turbidity (NTU)']
# Test model accuracy: 0.7227191413237924
# Test model recall: 0.7439024390243902
# Test model precision: 0.6654545454545454
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX', 'Wind Speed', 'rained']
# Test model accuracy: 0.740608228980322
# Test model recall: 0.7398373983739838
# Test model precision: 0.6920152091254753
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX', 'Wind Speed', 'Wind Angle']
# Test model accuracy: 0.7209302325581395
# Test model recall: 0.7479674796747967
# Test model precision: 0.6618705035971223
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX', 'Wind Speed', 'SNOW']
# Test model accuracy: 0.740608228980322
# Test model recall: 0.7398373983739838
# Test model precision: 0.6920152091254753
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX', 'Wind Speed', 'SNWD']
# Test model accuracy: 0.740608228980322
# Test model recall: 0.7398373983739838
# Test model precision: 0.6920152091254753
#
# Training model with: ['ODOSat%', 'TMIN', 'TMAX', 'Wind Speed', 'Sp Cond (uS/cm)']
# Test model accuracy: 0.740608228980322
# Test model recall: 0.7398373983739838
# Test model precision: 0.6920152091254753
#
# Final greedy columns: ['ODOSat%', 'TMIN', 'TMAX', 'Wind Speed']
# Final greedy accuracy 0.740608228980322
# Final greedy recall: 0.7398373983739838
# Final greedy precision: 0.6920152091254753
# Final greedy confusion matrix:
#  [[232  81]
#  [ 64 182]]
# Accuracy 0.740608228980322
# Recall: 0.7398373983739838
# Precision 0.6920152091254753
# Confusion Matrix:
#  [[232  81]
#  [ 64 182]]
# Mean accuracy: 0.7950532783697597

# %% [markdown]
# The imputed Turbidity in Marina does not seem to effect the model, however training on 2018 almost always performs worse than training on 2017 data.
